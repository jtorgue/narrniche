# %%
import dill
import json
import csv
from collections import defaultdict, Counter

# %%
raw_data_path = '../data/raw/'
processed_data_path = '../data/processed/'

raw_corpus_fn = raw_data_path + 'doreco_corpus.p'
raw_tes_fn = raw_data_path + 'tes/tes_'
metadata_fn = raw_data_path + 'doreco_files_metadata.csv'

languages_fn = processed_data_path + 'languages.json'
corpus_fn = processed_data_path + 'corpus.pkl'
corpus_narr_fn = processed_data_path + 'corpus_narr.pkl'
corpus_else_fn = processed_data_path + 'corpus_else.pkl'
tes_fn = processed_data_path + 'tes.pkl'
merged_tes_fn = processed_data_path + 'merged_tes.pkl'

# %%
def select_genres(corpus, files_metadata, genres):
    metadata = csv.DictReader(open(files_metadata), delimiter='\t')
    metadata = {(x['doculect'][:4],x['file']): (x['genre'],int(x['tokens'])) for x in metadata}
    genre_counts = Counter()
    new_corpus = defaultdict(lambda : {})
    for f in corpus:
        for fi in corpus[f]:
            fx = '_'.join(fi.split('_')[2:])
            genre = metadata[f[:4],fx][0]
            genre_counts[genre] += 1
            if genre in genres:
                new_corpus[f][fi] = corpus[f][fi]
    #print(genre_counts.most_common(10))
    return new_corpus

# %%
EXCLUDED_LANGS = {'ligh1234.csv', 'stan1290.csv', 'warl1254.csv'} # languages without TES files (2 not enough data & 1 english)
GENRES = {'personal narrative', 'traditional narrative', 'conversation', 'procedural'}
NARR_GENRES = {'personal narrative', 'traditional narrative'}
ELSE_GENRES = {'conversation', 'procedural'}

raw_corpus = dill.load(open(raw_corpus_fn, 'rb'))
raw_corpus = select_genres(raw_corpus, metadata_fn, GENRES)
corpus = {lang.split('.')[0]: entry for lang, entry in raw_corpus.items() if lang not in EXCLUDED_LANGS}
corpus_narr = select_genres(corpus, metadata_fn, NARR_GENRES)
corpus_else = select_genres(corpus, metadata_fn, ELSE_GENRES)
languages = sorted(list(corpus.keys()))
tes = {lang.split('.')[0]: dill.load(open(raw_tes_fn + lang + '.csv.p', 'rb')) for lang in languages}

# %%
json.dump(languages, open(languages_fn, 'w'))
dill.dump(corpus, open(corpus_fn, 'wb'))
dill.dump(corpus_narr, open(corpus_narr_fn, 'wb'))
dill.dump(corpus_else, open(corpus_else_fn, 'wb'))
dill.dump(tes, open(tes_fn, 'wb'))

# %%
import networkx as nx
from itertools import combinations, chain
from editdistance import eval as ed
from scipy.stats import entropy
from numpy.linalg import norm
import numpy as np
from collections import Counter

import gensim.downloader
wv = gensim.downloader.load('word2vec-google-news-300')
# train w2v on TES

def JSD(P, Q):
    _P = P / norm(P, ord=1)
    _Q = Q / norm(Q, ord=1)
    _M = 0.5 * (_P + _Q)
    return 0.5 * (entropy(_P, _M) + entropy(_Q, _M))

def merge_similar_tes_within(tes, te_words):
    merge = nx.Graph()
    merge.add_nodes_from(tes)
    tes_new, te_words_new = {}, {}
    for t1, t2 in combinations(tes,2):
        if t1 in t2 or t2 in t1 or ed(t1,t2) <= 1:
            merge.add_edge(t1,t2)
    for c in nx.connected_components(merge):
        best_c = max(c, key= lambda k : len(tes[k]))
        tes_new[best_c] = list(chain(*[tes[ci] for ci in c]))
        te_words_new[best_c] = sum([te_words[ci] for ci in c], Counter())
        #print('>>> MERGED', c)
    return tes_new, te_words_new

def merge_similar_tes_across(tes, te_words):
    merge_markers = nx.Graph()
    te_marker_pairs = [(te, marker) for te in tes for marker in tes[te] if len(tes[te][marker]) >= 5]
    for (tei,mrki),(tej,mrkj) in combinations(te_marker_pairs,2):
        if tei==tej: continue
        if set(te_words[tei][mrki]) & set(te_words[tej][mrkj]) != set():
            mrkic, mrkjc = mrki.strip('^$'), mrkj.strip('^$')
            minlen = min(len(mrkic),len(mrkjc))
            wi = te_words[tei][mrki]
            wj = te_words[tej][mrkj]
            jsd = (JSD(*zip(*[[wi[x],wj[x]] for x in sorted(set(wi)|set(wj))])))
            cos = (wv.similarity(tei,tej))
            jac = len(set(wi)&set(wj))/len(set(wi)|set(wj))
            form = mrkic[:minlen] == mrkjc[:minlen] or mrkic[-minlen:] == mrkjc[-minlen:]
            if cos >= 2/3 and jsd <= 2/3 and form:
                #print((tei,mrki),(tej,mrkj),'JSD=%.2f COS=%.2f JAC=%.2f FORM=%d' % (jsd, cos, jac,form))
                merge_markers.add_edge((tei,mrki), (tej,mrkj))
    for c in nx.connected_components(merge_markers):
        new_mrk = min([mrk for te,mrk in c],key = len)
        for te,mrk in c:
            tes[te][new_mrk] = tes[te][mrk]
            te_words[te][new_mrk] = te_words[te][mrk]
            if mrk != new_mrk: del tes[te][mrk], te_words[te][mrk]
    return tes, te_words

def merge_similar_tes(langtes):
    tes, te_words = langtes
    for k,v in tes.items():
        tes[k], te_words[k] = merge_similar_tes_within(v, te_words[k])
    #
    tes, te_words = merge_similar_tes_across(tes, te_words)
    return tes, te_words

# %%
merged_tes = dict()
for lang in tes:
    merged_tes[lang] = merge_similar_tes(tes[lang])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 3
#       1 merged_tes = dict()
#       2 for lang in tes:
# ----> 3     merged_tes[lang] = merge_similar_tes(tes[lang])
#
# Cell In[7], line 62, in merge_similar_tes(langtes)
#      60     tes[k], te_words[k] = merge_similar_tes_within(v, te_words[k])
#      61 #
# ---> 62 tes, te_words = merge_similar_tes_across(tes, te_words)
#      63 return tes, te_words
#
# Cell In[7], line 43, in merge_similar_tes_across(tes, te_words)
#      41 wj = te_words[tej][mrkj]
#      42 jsd = (JSD(*zip(*[[wi[x],wj[x]] for x in sorted(set(wi)|set(wj))])))
# ---> 43 cos = (wv.similarity(tei,tej))
#      44 jac = len(set(wi)&set(wj))/len(set(wi)|set(wj))
#      45 form = mrkic[:minlen] == mrkjc[:minlen] or mrkic[-minlen:] == mrkjc[-minlen:]
#
# File ~/desktop/phdwork/research/narrniche/.venv/lib/python3.13/site-packages/gensim/models/keyedvectors.py:1236, in KeyedVectors.similarity(self, w1, w2)
#    1220 def similarity(self, w1, w2):
#    1221     """Compute cosine similarity between two keys.
#    1222
#    1223     Parameters
#    (...)   1234
#    1235     """
# -> 1236     return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#
# File ~/desktop/phdwork/research/narrniche/.venv/lib/python3.13/site-packages/gensim/models/keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)    400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
#     405 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File ~/desktop/phdwork/research/narrniche/.venv/lib/python3.13/site-packages/gensim/models/keyedvectors.py:446, in KeyedVectors.get_vector(self, key, norm)
#     422 def get_vector(self, key, norm=False):
#     423     """Get the key's vector, as a 1D numpy array.
#     424
#     425     Parameters
#    (...)    444
#     445     """
# --> 446     index = self.get_index(key)
#     447     if norm:
#     448         self.fill_norms()
#
# File ~/desktop/phdwork/research/narrniche/.venv/lib/python3.13/site-packages/gensim/models/keyedvectors.py:420, in KeyedVectors.get_index(self, key, default)
#     418     return default
#     419 else:
# --> 420     raise KeyError(f"Key '{key}' not present")
#
# KeyError: "Key 'coque' not present"

# %%
merged_tes
# Out:
# {'anal1239': ({'say': {'do': [np.int32(43),
#      np.int32(46),
#      np.int32(74),
#      np.int32(123),
#      np.int32(130),
#      np.int32(154),
#      np.int32(184),
#      np.int32(343),
#      np.int32(354),
#      np.int32(372),
#      np.int32(517),
#      np.int32(561),
#      np.int32(652),
#      np.int32(703),
#      np.int32(747),
#      np.int32(753),
#      np.int32(815),
#      np.int32(830),
#      np.int32(835),
#      np.int32(837),
#      np.int32(840),
#      np.int32(846),
#      np.int32(884),
#      np.int32(903),
#      np.int32(909),
#      np.int32(910),
#      np.int32(920),
#      np.int32(921),
#      np.int32(926),
#      np.int32(941),
#      np.int32(942),
#      np.int32(945),
#      np.int32(950),
#      np.int32(984),
#      np.int32(1224),
#      np.int32(1233),
#      np.int32(1239),
#      np.int32(1295),
#      np.int32(1392),
#      np.int32(1493),
#      np.int32(1534),
#      np.int32(1535),
#      np.int32(1632),
#      np.int32(1697),
#      np.int32(1698),
#      np.int32(1887),
#      np.int32(1960),
#      np.int32(1965),
#      np.int32(1971),
#      np.int32(2014),
#      np.int32(2022),
#      np.int32(2041),
#      np.int32(2061),
#      np.int32(2063),
#      np.int32(2072),
#      np.int32(2440),
#      np.int32(2595),
#      np.int32(2608),
#      np.int32(2614),
#      np.int32(2669),
#      np.int32(2678),
#      np.int32(2679),
#      np.int32(2824),
#      np.int32(2826),
#      np.int32(2827),
#      np.int32(2842),
#      np.int32(427),
#      np.int32(469),
#      np.int32(472),
#      np.int32(474),
#      np.int32(482),
#      np.int32(489),
#      np.int32(504),
#      np.int32(512),
#      np.int32(521),
#      np.int32(545),
#      np.int32(582),
#      np.int32(595),
#      np.int32(604),
#      np.int32(680),
#      np.int32(682),
#      np.int32(735),
#      np.int32(748),
#      np.int32(752),
#      np.int32(756),
#      np.int32(757),
#      np.int32(798),
#      np.int32(862),
#      np.int32(883),
#      np.int32(905),
#      np.int32(1039),
#      np.int32(1040),
#      np.int32(1056),
#      np.int32(1111),
#      np.int32(1121),
#      np.int32(1160),
#      np.int32(1162),
#      np.int32(1165),
#      np.int32(1185),
#      np.int32(1192),
#      np.int32(1194),
#      np.int32(1217),
#      np.int32(1230),
#      np.int32(1232),
#      np.int32(1244),
#      np.int32(1254),
#      np.int32(1307),
#      np.int32(1313),
#      np.int32(1333),
#      np.int32(1353),
#      np.int32(1407),
#      np.int32(1456),
#      np.int32(1457),
#      np.int32(1458),
#      np.int32(1465),
#      np.int32(1466),
#      np.int32(1467),
#      np.int32(1486),
#      np.int32(1488),
#      np.int32(1489),
#      np.int32(1490),
#      np.int32(1492),
#      np.int32(1518),
#      np.int32(1519),
#      np.int32(1526),
#      np.int32(1531),
#      np.int32(1532),
#      np.int32(1536),
#      np.int32(1537),
#      np.int32(1538),
#      np.int32(1545),
#      np.int32(1546),
#      np.int32(1547),
#      np.int32(1550),
#      np.int32(1551),
#      np.int32(1554),
#      np.int32(1561),
#      np.int32(1568),
#      np.int32(1570),
#      np.int32(1572),
#      np.int32(516),
#      np.int32(527),
#      np.int32(677),
#      np.int32(681),
#      np.int32(686),
#      np.int32(687),
#      np.int32(977),
#      np.int32(1100),
#      np.int32(1531),
#      np.int32(1537),
#      np.int32(1568),
#      np.int32(1869),
#      np.int32(2121),
#      np.int32(2127),
#      np.int32(2131),
#      np.int32(2283),
#      np.int32(2290),
#      np.int32(2355),
#      np.int32(2441),
#      np.int32(2606),
#      np.int32(2721),
#      np.int32(2818)],
#     '^icha$': [np.int32(345),
#      np.int32(349),
#      np.int32(507),
#      np.int32(538),
#      np.int32(1584),
#      np.int32(2330)],
#     'chado': [np.int32(38), np.int32(689), np.int32(832), np.int32(2306)],
#     'achava': [np.int32(808), np.int32(816), np.int32(1544)],
#     'bal': [np.int32(132),
#      np.int32(134),
#      np.int32(135),
#      np.int32(177),
#      np.int32(180)],
#     'abu': [np.int32(1147),
#      np.int32(1874),
#      np.int32(1878),
#      np.int32(2586),
#      np.int32(2719)],
#     'asal': [np.int32(451), np.int32(475), np.int32(479)],
#     '^chal': [np.int32(116), np.int32(2828)],
#     '^chakaning$': [np.int32(805)],
#     '^hepahmom$': [np.int32(348)],
#     '^heng$': [np.int32(984)],
#     '^cha!$': [np.int32(1586)],
#     '^patuwng$': [np.int32(526)],
#     '^chahin$': [np.int32(2625)]},
#    'mother': {'^vanu': [np.int32(241),
#      np.int32(818),
#      np.int32(820),
#      np.int32(825),
#      np.int32(831),
#      np.int32(900),
#      np.int32(2021),
#      np.int32(2032),
#      np.int32(2072),
#      np.int32(2388),
#      np.int32(2391),
#      np.int32(2446),
#      np.int32(2465),
#      np.int32(160),
#      np.int32(164),
#      np.int32(567),
#      np.int32(570),
#      np.int32(792),
#      np.int32(799),
#      np.int32(809),
#      np.int32(871),
#      np.int32(879),
#      np.int32(880),
#      np.int32(885),
#      np.int32(887),
#      np.int32(903),
#      np.int32(914),
#      np.int32(919),
#      np.int32(941),
#      np.int32(1250),
#      np.int32(1279),
#      np.int32(1314),
#      np.int32(1321),
#      np.int32(1338),
#      np.int32(1347),
#      np.int32(1361),
#      np.int32(1375),
#      np.int32(1411),
#      np.int32(1432),
#      np.int32(1808),
#      np.int32(1980),
#      np.int32(1988),
#      np.int32(2024),
#      np.int32(2034),
#      np.int32(2035),
#      np.int32(2040),
#      np.int32(2079),
#      np.int32(2091),
#      np.int32(2094),
#      np.int32(2297),
#      np.int32(2304),
#      np.int32(2314),
#      np.int32(2332),
#      np.int32(2427),
#      np.int32(2431),
#      np.int32(2440),
#      np.int32(2473),
#      np.int32(2479),
#      np.int32(2481)],
#     '^ajung$': [np.int32(1286),
#      np.int32(1287),
#      np.int32(1288),
#      np.int32(1289)],
#     '^anu$': [np.int32(2092), np.int32(2468)],
#     '^pi$': [np.int32(624), np.int32(646)],
#     'rung$': [np.int32(2086), np.int32(2466)],
#     '^chakaning$': [np.int32(805)],
#     '^nucha$': [np.int32(239)],
#     '^ahal$': [np.int32(2045)]},
#    'take': {'li': [np.int32(549),
#      np.int32(550),
#      np.int32(685),
#      np.int32(722),
#      np.int32(781),
#      np.int32(820),
#      np.int32(1148),
#      np.int32(1154),
#      np.int32(1158),
#      np.int32(1164),
#      np.int32(1185),
#      np.int32(1242),
#      np.int32(1243),
#      np.int32(1252),
#      np.int32(1732),
#      np.int32(1919),
#      np.int32(2014),
#      np.int32(2465),
#      np.int32(2577),
#      np.int32(2628),
#      np.int32(2631),
#      np.int32(2633),
#      np.int32(2726),
#      np.int32(2727),
#      np.int32(2734),
#      np.int32(2735),
#      np.int32(2736),
#      np.int32(2836),
#      np.int32(2837)],
#     'thu$': [np.int32(790),
#      np.int32(791),
#      np.int32(1543),
#      np.int32(765),
#      np.int32(788),
#      np.int32(1114),
#      np.int32(1115),
#      np.int32(1361),
#      np.int32(1396),
#      np.int32(1422),
#      np.int32(1547),
#      np.int32(2323)],
#     'akhal': [np.int32(2276), np.int32(2466), np.int32(2476), np.int32(2478)],
#     '^thunu$': [np.int32(414), np.int32(1572), np.int32(1830)],
#     'supe': [np.int32(99), np.int32(750)],
#     '^asu': [np.int32(728), np.int32(2076), np.int32(2646)],
#     '^phe$': [np.int32(1958), np.int32(1967)],
#     '^nato$': [np.int32(77), np.int32(1279)],
#     'tangna$': [np.int32(2311), np.int32(2330)],
#     '^ahungdun$': [np.int32(1421)],
#     '^jungpale$': [np.int32(2166)],
#     '^aunghin$': [np.int32(2240)],
#     '^petung$': [np.int32(12)],
#     '^lungam$': [np.int32(1291)],
#     '^apemin$': [np.int32(1841)],
#     '^ihrowl$': [np.int32(2512)]},
#    'give': {'ape': [np.int32(439),
#      np.int32(441),
#      np.int32(446),
#      np.int32(451),
#      np.int32(455),
#      np.int32(477),
#      np.int32(549),
#      np.int32(681),
#      np.int32(682),
#      np.int32(684),
#      np.int32(689),
#      np.int32(785),
#      np.int32(788),
#      np.int32(1040),
#      np.int32(1061),
#      np.int32(1149),
#      np.int32(1152),
#      np.int32(1153),
#      np.int32(1207),
#      np.int32(1209),
#      np.int32(1210),
#      np.int32(1215),
#      np.int32(1216),
#      np.int32(1243),
#      np.int32(2057),
#      np.int32(2061),
#      np.int32(2069),
#      np.int32(2081),
#      np.int32(2309)],
#     '^vatho$': [np.int32(695),
#      np.int32(696),
#      np.int32(701),
#      np.int32(703),
#      np.int32(708),
#      np.int32(714),
#      np.int32(715),
#      np.int32(718),
#      np.int32(1329),
#      np.int32(1330)],
#     '^tho': [np.int32(705),
#      np.int32(728),
#      np.int32(730),
#      np.int32(732),
#      np.int32(734),
#      np.int32(737),
#      np.int32(1505),
#      np.int32(1506),
#      np.int32(1897)],
#     '^penu$': [np.int32(1222), np.int32(1314), np.int32(1321), np.int32(2613)],
#     '^kahepe$': [np.int32(2658), np.int32(2832)],
#     '^hueh$': [np.int32(2086), np.int32(2090)],
#     '^dabu$': [np.int32(1309), np.int32(1334)],
#     'echa$': [np.int32(256), np.int32(532)],
#     '^akhehtal$': [np.int32(670)],
#     '^anituwng$': [np.int32(1386)],
#     '^chung$': [np.int32(1221)]},
#    'man': {'^lera': [np.int32(1143),
#      np.int32(1144),
#      np.int32(1147),
#      np.int32(1153),
#      np.int32(1175),
#      np.int32(1186),
#      np.int32(1221)],
#     '^pakan': [np.int32(417),
#      np.int32(418),
#      np.int32(423),
#      np.int32(434),
#      np.int32(469),
#      np.int32(491),
#      np.int32(502),
#      np.int32(504)],
#     '^simpa$': [np.int32(67),
#      np.int32(1099),
#      np.int32(1297),
#      np.int32(410),
#      np.int32(1897),
#      np.int32(1955),
#      np.int32(1956),
#      np.int32(1957)],
#     'avangpa': [np.int32(1810),
#      np.int32(1825),
#      np.int32(1826),
#      np.int32(1846)],
#     '^amaputhi$': [np.int32(1849),
#      np.int32(1904),
#      np.int32(1938),
#      np.int32(1951)],
#     '^vangsang$': [np.int32(252), np.int32(258)],
#     '^tepang$': [np.int32(71), np.int32(467)],
#     '^nung$': [np.int32(449), np.int32(511)],
#     '^pihol-pisa$': [np.int32(953)],
#     '^asintuwng$': [np.int32(553)],
#     '^sonthipa$': [np.int32(117)],
#     '^ilu$': [np.int32(253)],
#     '^lenu$': [np.int32(1222)],
#     '^ala': [np.int32(103),
#      np.int32(114),
#      np.int32(546),
#      np.int32(563),
#      np.int32(617),
#      np.int32(619),
#      np.int32(1347),
#      np.int32(1439),
#      np.int32(1440),
#      np.int32(1461),
#      np.int32(1465),
#      np.int32(1466),
#      np.int32(1479),
#      np.int32(1490),
#      np.int32(1491)]},
#    'do': {'nato': [np.int32(126),
#      np.int32(183),
#      np.int32(188),
#      np.int32(1036),
#      np.int32(2436),
#      np.int32(2655),
#      np.int32(2731),
#      np.int32(250),
#      np.int32(276),
#      np.int32(294),
#      np.int32(1035)],
#     '^dohin': [np.int32(484), np.int32(674), np.int32(1394), np.int32(2371)],
#     '^chaka': [np.int32(627),
#      np.int32(720),
#      np.int32(1206),
#      np.int32(1730),
#      np.int32(2274),
#      np.int32(2276),
#      np.int32(2660)],
#     '^too$': [np.int32(1052), np.int32(1151), np.int32(1190)],
#     'mano$': [np.int32(41), np.int32(1706)],
#     'tow': [np.int32(2488), np.int32(2573)],
#     '^kato$': [np.int32(611), np.int32(2796)],
#     '^vane$': [np.int32(249), np.int32(361)],
#     'doo$': [np.int32(1586), np.int32(2519)],
#     'nada$': [np.int32(44), np.int32(2732)],
#     '^tepang$': [np.int32(22), np.int32(1559)],
#     '^kado': [np.int32(1983), np.int32(2417)],
#     'ena': [np.int32(138), np.int32(254)],
#     '^vachohrang$': [np.int32(1520)],
#     '^hesonseenu$': [np.int32(1984)],
#     '^chavasin$': [np.int32(207)],
#     '^pakaning$': [np.int32(548)],
#     '^dorangnu$': [np.int32(1922)],
#     '^dohlonu$': [np.int32(1434)],
#     '^dotiinu$': [np.int32(2526)],
#     '^hludoh$': [np.int32(274)],
#     '^dameme$': [np.int32(1347)],
#     '^vatoma$': [np.int32(2662)],
#     '^mikhe$': [np.int32(723)],
#     '^adong$': [np.int32(1521)],
#     '^ihal$': [np.int32(50)]},
#    'time': {'^arang': [np.int32(409),
#      np.int32(518),
#      np.int32(653),
#      np.int32(802),
#      np.int32(872),
#      np.int32(951),
#      np.int32(1098),
#      np.int32(1438),
#      np.int32(1504),
#      np.int32(1771),
#      np.int32(2096),
#      np.int32(2179),
#      np.int32(2412)],
#     'ika$': [np.int32(221),
#      np.int32(2152),
#      np.int32(2509),
#      np.int32(2524),
#      np.int32(2525),
#      np.int32(2528)],
#     '^asan': [np.int32(2),
#      np.int32(91),
#      np.int32(336),
#      np.int32(508),
#      np.int32(1296),
#      np.int32(1805),
#      np.int32(1978),
#      np.int32(2258)],
#     'matam$': [np.int32(1768), np.int32(2097), np.int32(2833)],
#     '^tum': [np.int32(908),
#      np.int32(2527),
#      np.int32(2546),
#      np.int32(2547),
#      np.int32(2794)],
#     '^mavati$': [np.int32(1861), np.int32(1892)],
#     'hring$': [np.int32(1623), np.int32(2508)],
#     'una': [np.int32(1939), np.int32(2552)],
#     '^vakhang$': [np.int32(567)],
#     '^hangdee$': [np.int32(1860)],
#     '^hantha$': [np.int32(1406)],
#     '^tisung$': [np.int32(17)],
#     '^mobile$': [np.int32(697)],
#     '^etolo$': [np.int32(319)],
#     '^vaten$': [np.int32(422)],
#     '^vahlo$': [np.int32(556)],
#     '^amthe$': [np.int32(1890)],
#     '^kasol$': [np.int32(1896)],
#     '^isow$': [np.int32(947)],
#     '^irangrang$': [np.int32(2517)],
#     '^pathung$': [np.int32(60)],
#     '^nama$': [np.int32(440)]},
#    'king': {'gtho': [np.int32(656),
#      np.int32(658),
#      np.int32(663),
#      np.int32(735),
#      np.int32(736),
#      np.int32(773),
#      np.int32(776),
#      np.int32(780),
#      np.int32(782),
#      np.int32(783),
#      np.int32(791),
#      np.int32(796),
#      np.int32(1141),
#      np.int32(1142),
#      np.int32(1180),
#      np.int32(1181),
#      np.int32(1208),
#      np.int32(1219),
#      np.int32(1220),
#      np.int32(1242),
#      np.int32(1245),
#      np.int32(1252),
#      np.int32(1845),
#      np.int32(1846),
#      np.int32(1854),
#      np.int32(1876),
#      np.int32(1880),
#      np.int32(1887),
#      np.int32(1893),
#      np.int32(1924),
#      np.int32(1927),
#      np.int32(1941)],
#     '^aruwng': [np.int32(771),
#      np.int32(1153),
#      np.int32(1166),
#      np.int32(1202),
#      np.int32(1875),
#      np.int32(2117),
#      np.int32(2166),
#      np.int32(2257),
#      np.int32(2258),
#      np.int32(2284)],
#     '^dahki$': [np.int32(2124),
#      np.int32(2130),
#      np.int32(2133),
#      np.int32(2137),
#      np.int32(2142),
#      np.int32(2149),
#      np.int32(2154)],
#     '^vathi': [np.int32(1144), np.int32(2287)],
#     '^maharaja$': [np.int32(717)],
#     '^akhong$': [np.int32(2174)],
#     '^sedoh$': [np.int32(1204)],
#     '^sumte$': [np.int32(2165)]},
#    'tell': {'^asu': [np.int32(1748),
#      np.int32(1749),
#      np.int32(1750),
#      np.int32(1754),
#      np.int32(1755),
#      np.int32(1761),
#      np.int32(2600),
#      np.int32(2679)],
#     'kaning$': [np.int32(481),
#      np.int32(549),
#      np.int32(558),
#      np.int32(568),
#      np.int32(1207),
#      np.int32(1361),
#      np.int32(1436),
#      np.int32(1747),
#      np.int32(1977),
#      np.int32(2257),
#      np.int32(2401)],
#     '^ning': [np.int32(656),
#      np.int32(1742),
#      np.int32(1745),
#      np.int32(1767)],
#     '^vacha$': [np.int32(446), np.int32(449), np.int32(456)],
#     '^atang$': [np.int32(470), np.int32(515)],
#     '^vovo$': [np.int32(436)]},
#    'trap': {'atang': [np.int32(417),
#      np.int32(418),
#      np.int32(420),
#      np.int32(470),
#      np.int32(486),
#      np.int32(487),
#      np.int32(491),
#      np.int32(493),
#      np.int32(496),
#      np.int32(497),
#      np.int32(511),
#      np.int32(515),
#      np.int32(1400),
#      np.int32(1813),
#      np.int32(1814),
#      np.int32(1815),
#      np.int32(1816),
#      np.int32(1817),
#      np.int32(1827),
#      np.int32(1828),
#      np.int32(1831),
#      np.int32(1835),
#      np.int32(1841),
#      np.int32(1844),
#      np.int32(1847),
#      np.int32(1856)],
#     'changva': [np.int32(1399),
#      np.int32(1402),
#      np.int32(1403),
#      np.int32(1421),
#      np.int32(1423),
#      np.int32(1425),
#      np.int32(1426)],
#     '^amin$': [np.int32(499), np.int32(868), np.int32(869), np.int32(1840)],
#     '^nangto$': [np.int32(843)],
#     '^lelova$': [np.int32(1832)]},
#    'call': {'on$': [np.int32(612),
#      np.int32(613),
#      np.int32(1525),
#      np.int32(1548),
#      np.int32(1558),
#      np.int32(1575),
#      np.int32(1577),
#      np.int32(1688),
#      np.int32(1850),
#      np.int32(1884),
#      np.int32(2021),
#      np.int32(2039),
#      np.int32(2052),
#      np.int32(2053),
#      np.int32(2066)],
#     '^angnar$': [np.int32(991), np.int32(998), np.int32(1003)],
#     '^no$': [np.int32(1765), np.int32(1809), np.int32(2035), np.int32(2063)],
#     'ish$': [np.int32(1), np.int32(1023)],
#     'jah': [np.int32(1736), np.int32(1764)],
#     '^khuwngto$': [np.int32(91)],
#     '^adoluna$': [np.int32(1450)],
#     '^mobile$': [np.int32(697)],
#     '^paring$': [np.int32(1073)],
#     '^vadasi$': [np.int32(1659)],
#     '^dijenu$': [np.int32(2580)],
#     '^ithum$': [np.int32(72)],
#     '^dohe$': [np.int32(1226)],
#     '^aruwngtuwng$': [np.int32(1153)],
#     '^salhmi$': [np.int32(263)],
#     '^idahe$': [np.int32(76)],
#     '^meeje$': [np.int32(354)]},
#    'ask': {'pachool': [np.int32(793),
#      np.int32(2069),
#      np.int32(1025),
#      np.int32(1029),
#      np.int32(1759),
#      np.int32(2336),
#      np.int32(2489),
#      np.int32(2496),
#      np.int32(2592)],
#     '^daki': [np.int32(1276), np.int32(1892), np.int32(2045), np.int32(2056)],
#     '^amh': [np.int32(1028), np.int32(2354), np.int32(2366)],
#     '^nihe': [np.int32(2196), np.int32(2316)],
#     '^nal': [np.int32(22), np.int32(265)],
#     '^danite$': [np.int32(189), np.int32(399)],
#     'asal': [np.int32(475), np.int32(479)],
#     'achara$': [np.int32(161), np.int32(1375)],
#     '^vadavakhu$': [np.int32(356)],
#     '^nanghinte$': [np.int32(2370)],
#     '^ahrorva$': [np.int32(1931)],
#     '^dahrang$': [np.int32(2234)],
#     '^ikanava$': [np.int32(2359)],
#     '^chadoh$': [np.int32(1135)],
#     '^peeche$': [np.int32(342)],
#     '^dahlu$': [np.int32(1035)],
#     '^vadaje$': [np.int32(1263)],
#     '^kumja$': [np.int32(1033)],
#     '^achal$': [np.int32(164)],
#     '^maram$': [np.int32(2118)]},
#    'old': {'^lap': [np.int32(109),
#      np.int32(205),
#      np.int32(208),
#      np.int32(536),
#      np.int32(873),
#      np.int32(894),
#      np.int32(898),
#      np.int32(1527),
#      np.int32(1533),
#      np.int32(1538),
#      np.int32(1551),
#      np.int32(1582)],
#     '^palu$': [np.int32(73),
#      np.int32(75),
#      np.int32(76),
#      np.int32(79),
#      np.int32(82),
#      np.int32(933)],
#     '^aval$': [np.int32(2522), np.int32(2524), np.int32(2526), np.int32(2528)],
#     '^arang$': [np.int32(1446), np.int32(1771), np.int32(2096)],
#     '^asanki$': [np.int32(1267), np.int32(1279)],
#     '^kum$': [np.int32(935), np.int32(1034)],
#     'angr': [np.int32(789), np.int32(928)],
#     '^ida': [np.int32(943), np.int32(1534)],
#     '^vau': [np.int32(1490), np.int32(1510)],
#     '^thumnu$': [np.int32(800)],
#     '^rangnu$': [np.int32(1919)],
#     '^vabuh$': [np.int32(209)]},
#    'see': {'thi': [np.int32(38),
#      np.int32(198),
#      np.int32(199),
#      np.int32(203),
#      np.int32(204),
#      np.int32(297),
#      np.int32(298),
#      np.int32(696),
#      np.int32(712),
#      np.int32(1144),
#      np.int32(1274),
#      np.int32(1309),
#      np.int32(1311),
#      np.int32(1381),
#      np.int32(1384),
#      np.int32(1419),
#      np.int32(1987)],
#     'adang': [np.int32(90), np.int32(1501), np.int32(2620), np.int32(2642)],
#     '^chakave$': [np.int32(2349), np.int32(2350)],
#     '^nasu': [np.int32(314), np.int32(2671)],
#     'wngh': [np.int32(2410), np.int32(2503)],
#     'suh': [np.int32(2408), np.int32(2445)],
#     'ungte$': [np.int32(404), np.int32(1769)],
#     'dak': [np.int32(1758), np.int32(2171)],
#     '^palahtuwng$': [np.int32(2386)],
#     '^thochamo$': [np.int32(2021)],
#     '^ralkhe$': [np.int32(1678)],
#     '^tubo$': [np.int32(2730)],
#     '^tangsin$': [np.int32(760)]},
#    'child': {'chara': [np.int32(161),
#      np.int32(654),
#      np.int32(660),
#      np.int32(663),
#      np.int32(666),
#      np.int32(674),
#      np.int32(714),
#      np.int32(715),
#      np.int32(718),
#      np.int32(723),
#      np.int32(727),
#      np.int32(729),
#      np.int32(741),
#      np.int32(742),
#      np.int32(744),
#      np.int32(746),
#      np.int32(747),
#      np.int32(781),
#      np.int32(792),
#      np.int32(877),
#      np.int32(1262),
#      np.int32(1330),
#      np.int32(1356),
#      np.int32(1381),
#      np.int32(1384),
#      np.int32(1411),
#      np.int32(1809),
#      np.int32(1895),
#      np.int32(1897),
#      np.int32(2547),
#      np.int32(2711)],
#     '^ipu$': [np.int32(396), np.int32(399)],
#     '^sangramchang$': [np.int32(789)],
#     '^mowng$': [np.int32(400)],
#     '^nucha$': [np.int32(239)],
#     '^achal$': [np.int32(164)]},
#    'live': {'pal$': [np.int32(522),
#      np.int32(551),
#      np.int32(552),
#      np.int32(555),
#      np.int32(878),
#      np.int32(944),
#      np.int32(1137),
#      np.int32(1138),
#      np.int32(1139),
#      np.int32(1252),
#      np.int32(1259),
#      np.int32(1337),
#      np.int32(1432),
#      np.int32(1694),
#      np.int32(2616),
#      np.int32(2779),
#      np.int32(2780),
#      np.int32(2800),
#      np.int32(2805)],
#     'hring': [np.int32(14),
#      np.int32(949),
#      np.int32(2273),
#      np.int32(2470),
#      np.int32(2507)],
#     '^am$': [np.int32(2692), np.int32(2694), np.int32(2696)],
#     'eram': [np.int32(145), np.int32(1980)],
#     '^achungnu$': [np.int32(1992)],
#     '^paljenu$': [np.int32(2482)],
#     '^palcha$': [np.int32(1336)],
#     '^vaten$': [np.int32(422)],
#     '^nahal$': [np.int32(719)],
#     '^hmun$': [np.int32(796)]},
#    'make': {'see': [np.int32(1094),
#      np.int32(1392),
#      np.int32(1471),
#      np.int32(1473),
#      np.int32(1474),
#      np.int32(1476),
#      np.int32(2001)],
#     '^pi': [np.int32(755),
#      np.int32(759),
#      np.int32(760),
#      np.int32(1159),
#      np.int32(2466),
#      np.int32(2477)],
#     '^patha$': [np.int32(132), np.int32(134), np.int32(135)],
#     '^kasempe$': [np.int32(1358), np.int32(1391)],
#     '^parim$': [np.int32(4), np.int32(651)],
#     '^hmi$': [np.int32(340), np.int32(341), np.int32(863)],
#     '^sanu$': [np.int32(2002), np.int32(2003)],
#     '^bol$': [np.int32(322), np.int32(324)],
#     '^vanhuwlva$': [np.int32(1997)],
#     '^alethunu$': [np.int32(2393)],
#     '^pakaning$': [np.int32(548)],
#     '^sosinna$': [np.int32(1095)],
#     '^apalum$': [np.int32(2816)],
#     '^keeko$': [np.int32(347)],
#     '^sedoh$': [np.int32(1204)]},
#    'get': {'^pha': [np.int32(13),
#      np.int32(1042),
#      np.int32(1050),
#      np.int32(1057),
#      np.int32(1768)],
#     '^edu$': [np.int32(1361), np.int32(1495)],
#     '^sin$': [np.int32(1326), np.int32(1729), np.int32(2783)],
#     'apo': [np.int32(1821), np.int32(2397), np.int32(2776)],
#     '^thi$': [np.int32(140), np.int32(1371)],
#     'hinu': [np.int32(2044), np.int32(2090)],
#     '^athi': [np.int32(541), np.int32(543)],
#     '^akhehvahle$': [np.int32(689)],
#     '^vajungtum$': [np.int32(37)],
#     '^vapungnon$': [np.int32(2020)],
#     '^sopapammi$': [np.int32(2407)],
#     '^lentangki$': [np.int32(2593)],
#     '^vaungcha$': [np.int32(2299)],
#     '^chahlo$': [np.int32(1312)],
#     '^uhnu$': [np.int32(565)],
#     '^idal$': [np.int32(943)],
#     '^chookaning$': [np.int32(1702)],
#     '^thimanu$': [np.int32(139)],
#     '^vathung$': [np.int32(1360)],
#     '^nikheh$': [np.int32(569)]},
#    'son': {'chapa': [np.int32(892),
#      np.int32(907),
#      np.int32(912),
#      np.int32(918),
#      np.int32(926),
#      np.int32(940),
#      np.int32(945),
#      np.int32(1347),
#      np.int32(2281),
#      np.int32(2284),
#      np.int32(2286),
#      np.int32(2289),
#      np.int32(2293),
#      np.int32(2472),
#      np.int32(2481),
#      np.int32(2685),
#     '^mava': [np.int32(2223), np.int32(2227)],
#     '^vanepate$': [np.int32(2251)],
#     '^a-althu$': [np.int32(1375)]},
#    'boy': {'^sinpa$': [np.int32(874),
#      np.int32(2298),
#      np.int32(2302),
#      np.int32(2305),
#      np.int32(2309),
#      np.int32(2324),
#      np.int32(2336),
#      np.int32(2363)],
#     '^ala': [np.int32(337),
#      np.int32(343),
#      np.int32(1734),
#      np.int32(1765),
#      np.int32(2188),
#      np.int32(2193),
#      np.int32(2214),
#      np.int32(2406)],
#     'hebe': [np.int32(1393), np.int32(2316)],
#     '^nanghinte$': [np.int32(2370)],
#     '^a-althu$': [np.int32(1375)],
#     '^asinibe$': [np.int32(2345)],
#     '^vathoo$': [np.int32(1509)],
#     '^vapate$': [np.int32(1979)],
#     '^pipa$': [np.int32(1507)],
#     '^suwkaning$': [np.int32(1977)],
#     '^vasora$': [np.int32(2194)],
#     '^pasin$': [np.int32(1366)],
#     '^chavangpa$': [np.int32(1817)],
#     '^ekhal$': [np.int32(1419)]},
#    'water': {'^du': [np.int32(92),
#      np.int32(197),
#      np.int32(204),
#      np.int32(227),
#      np.int32(229),
#      np.int32(231),
#      np.int32(238),
#      np.int32(844),
#      np.int32(1112),
#      np.int32(1367),
#      np.int32(1368),
#      np.int32(1397),
#      np.int32(1419),
#      np.int32(1619),
#      np.int32(1641),
#      np.int32(2363),
#      np.int32(2421),
#      np.int32(2422),
#      np.int32(2480)],
#     '^naju': [np.int32(228), np.int32(230)],
#     'asem': [np.int32(1400), np.int32(1401)],
#     'ane$': [np.int32(85), np.int32(98)],
#     '^chaldu$': [np.int32(116)],
#     '^kucham$': [np.int32(865)],
#     '^chodu$': [np.int32(97)]},
#    'young': {'^matum': [np.int32(561),
#      np.int32(679),
#      np.int32(686),
#      np.int32(689),
#      np.int32(691),
#      np.int32(727),
#      np.int32(1128),
#      np.int32(1129),
#      np.int32(1131),
#      np.int32(1134),
#      np.int32(1483)],
#     '^alal$': [np.int32(114),
#      np.int32(617),
#      np.int32(619),
#      np.int32(1439),
#      np.int32(1440),
#      np.int32(1465),
#      np.int32(1479),
#      np.int32(1490),
#      np.int32(1491)],
#     'nahla$': [np.int32(1267),
#      np.int32(1441),
#      np.int32(1540),
#      np.int32(1561),
#      np.int32(1578),
#      np.int32(1585)],
#     '^vane': [np.int32(361), np.int32(2251)]},
#    'know': {'thi': [np.int32(119),
#      np.int32(139),
#      np.int32(188),
#      np.int32(379),
#      np.int32(696),
#      np.int32(1101),
#      np.int32(1327),
#      np.int32(1495),
#      np.int32(1500),
#      np.int32(2185),
#      np.int32(2212),
#      np.int32(2287),
#      np.int32(2293),
#      np.int32(2448),
#      np.int32(2464),
#      np.int32(2528),
#      np.int32(2649),
#      np.int32(2667),
#      np.int32(2745),
#      np.int32(2798)],
#     '^ito$': [np.int32(267), np.int32(268), np.int32(269)],
#     '^avanghol$': [np.int32(323)],
#     '^varen$': [np.int32(1001)],
#     '^daniteh$': [np.int32(737)],
#     '^dathal$': [np.int32(2254)],
#     '^angnar$': [np.int32(992)]},
#    'field': {'hli': [np.int32(163),
#      np.int32(166),
#      np.int32(525),
#      np.int32(533),
#      np.int32(552),
#      np.int32(1999),
#      np.int32(2006),
#      np.int32(2007),
#      np.int32(2012),
#      np.int32(2015),
#      np.int32(2098),
#      np.int32(2488),
#      np.int32(2497),
#      np.int32(2503),
#      np.int32(2504),
#      np.int32(2513),
#      np.int32(2528),
#      np.int32(2538),
#      np.int32(2539),
#      np.int32(2547),
#      np.int32(2551),
#      np.int32(2554),
#      np.int32(2557),
#      np.int32(2578),
#      np.int32(2772),
#      np.int32(2773)],
#     '^chapibal$': [np.int32(2573)],
#     '^naphuwm$': [np.int32(2774)]},
#    'tree': {'^thing': [np.int32(105),
#      np.int32(366),
#      np.int32(371),
#      np.int32(927),
#      np.int32(946),
#      np.int32(1363),
#      np.int32(1364),
#      np.int32(1369),
#      np.int32(1371),
#      np.int32(1384),
#      np.int32(1387),
#      np.int32(1472),
#      np.int32(1714),
#      np.int32(1718),
#      np.int32(1866),
#      np.int32(2540),
#      np.int32(2721)],
#     '^pavung$': [np.int32(905), np.int32(907), np.int32(910), np.int32(926)],
#     'bol$': [np.int32(769), np.int32(778), np.int32(929)],
#     '^hangkalso$': [np.int32(1876), np.int32(1877)],
#     '^sangkha$': [np.int32(2542)]},
#    'snake': {'^paruwl$': [np.int32(285),
#      np.int32(286),
#      np.int32(288),
#      np.int32(546),
#      np.int32(562),
#      np.int32(565),
#      np.int32(566),
#      np.int32(568),
#      np.int32(572),
#      np.int32(573),
#      np.int32(583),
#      np.int32(585),
#      np.int32(597),
#      np.int32(601),
#      np.int32(602),
#      np.int32(607),
#      np.int32(610),
#      np.int32(614),
#      np.int32(619),
#      np.int32(626),
#      np.int32(635),
#      np.int32(640),
#      np.int32(642),
#      np.int32(645),
#      np.int32(978)],
#     '^ipathope$': [np.int32(615)],
#     '^vahrah$': [np.int32(636)]},
#    'cultivate': {'^hli': [np.int32(521),
#      np.int32(522),
#      np.int32(552),
#      np.int32(1999),
#      np.int32(2006),
#      np.int32(2007),
#      np.int32(2009),
#      np.int32(2012),
#      np.int32(2015),
#      np.int32(2098),
#      np.int32(2203),
#      np.int32(2488),
#      np.int32(2503),
#      np.int32(2504),
#      np.int32(2508),
#      np.int32(2517),
#      np.int32(2539),
#      np.int32(2547),
#      np.int32(2775)],
#     '^vee': [np.int32(2500),
#      np.int32(2559),
#      np.int32(2563),
#      np.int32(2567),
#      np.int32(2568),
#      np.int32(2570)],
#     '^vavethung$': [np.int32(1970)],
#     '^tuvarende$': [np.int32(2538)]},
#    'keep': {'^vachar': [np.int32(723), np.int32(741), np.int32(2761)],
#     '^athi$': [np.int32(2354), np.int32(2738)],
#     '^huw$': [np.int32(1117), np.int32(1118)],
#     '^vavang$': [np.int32(316), np.int32(1665), np.int32(1666)],
#     'doh$': [np.int32(237), np.int32(886), np.int32(1661)],
#     'vi$': [np.int32(47), np.int32(385)],
#     'mja': [np.int32(36), np.int32(1347)],
#     'nath': [np.int32(233), np.int32(1264)],
#     '^thungkhe$': [np.int32(24)],
#     '^peepeeno$': [np.int32(262)],
#     '^apathim$': [np.int32(2747)],
#     '^pejava$': [np.int32(100)],
#     '^vajungjung$': [np.int32(2296)],
#     '^pathama$': [np.int32(2453)],
#     '^kanacha$': [np.int32(2355)]},
#    'put': {'thal': [np.int32(205),
#      np.int32(209),
#      np.int32(578),
#      np.int32(1183),
#      np.int32(2292),
#      np.int32(2364),
#      np.int32(2375),
#      np.int32(2381),
#      np.int32(2397),
#      np.int32(2479)],
#     '^katha$': [np.int32(1341), np.int32(2754), np.int32(2755)],
#     'doh$': [np.int32(208), np.int32(211), np.int32(1282), np.int32(2295)],
#     'ahmom$': [np.int32(348), np.int32(2829)],
#     'napa$': [np.int32(2657), np.int32(2791)],
#     '^vare': [np.int32(1845), np.int32(1847)],
#     '^vaparoonate$': [np.int32(1477)],
#     '^ekhumcha$': [np.int32(1342)],
#     '^vahmiha$': [np.int32(2361)]},
#    'eye': {'hmi': [np.int32(298),
#      np.int32(631),
#      np.int32(632),
#      np.int32(710),
#      np.int32(711),
#      np.int32(713),
#      np.int32(864),
#      np.int32(1254),
#      np.int32(1311),
#      np.int32(2038),
#      np.int32(2046),
#      np.int32(2058),
#      np.int32(2064),
#      np.int32(2070),
#      np.int32(2072),
#      np.int32(2275),
#      np.int32(2276),
#      np.int32(2361),
#      np.int32(2451),
#      np.int32(2466),
#      np.int32(2476),
#      np.int32(2478),
#      np.int32(2479),
#      np.int32(2480),
#      np.int32(2657)],
#     '^vahm': [np.int32(708), np.int32(2460)]},
#    'leave': {'pathi': [np.int32(1372),
#      np.int32(1415),
#      np.int32(2399),
#      np.int32(2401)],
#     '^hung$': [np.int32(1133), np.int32(1889), np.int32(2403)],
#     '^vang$': [np.int32(1612), np.int32(1613), np.int32(1653)],
#     'kam': [np.int32(883), np.int32(1529), np.int32(2032)],
# ...
#    'interfere': {'^timmerriji$': Counter({np.str_('^timmerriji$'): 1})},
#    'involve': {'^timmirrija$': Counter({np.str_('^timmirrija$'): 1})},
#    'capable': {'^alla:jjo:d$': Counter({np.str_('^alla:jjo:d$'): 1})},
#    'revive': {'^nijade:t$': Counter({np.str_('^nijade:t$'): 1})},
#    'faith': {'^w?i:ma:n$': Counter({np.str_('^w?i:ma:n$'): 1})},
#    'governement': {'^bitha:je:b$': Counter({np.str_('^bitha:je:b$'): 1})},
#    'institution': {'^it?igirne:b$': Counter({np.str_('^it?igirne:b$'): 1})},
#    'consequence': {'^ba:sajjasej$': Counter({np.str_('^ba:sajjasej$'): 1})},
#    'solve': {'^hillina:hi:$': Counter({np.str_('^hillina:hi:$'): 1})},
#    'worried': {'^hemmi:ja:ba$': Counter({np.str_('^hemmi:ja:ba$'): 1})},
#    'expect': {'^sajjasi:na$': Counter({np.str_('^sajjasi:na$'): 1})},
#    '"if': {'^saga:mte:ne:k$': Counter({np.str_('^saga:mte:ne:k$'): 1})},
#    'amount': {'^hi:to:kna$': Counter({np.str_('^hi:to:kna$'): 1})},
#    'preserve': {'^idi:bne:t$': Counter({np.str_('^idi:bne:t$'): 1})},
#    'allow': {'^tindije:na$': Counter({np.str_('^tindije:na$'): 1})},
#    'quarelle': {'^amdera:jti:t$': Counter({np.str_('^amdera:jti:t$'): 1})},
#    'whithout': {'^ba:mka:r$': Counter({np.str_('^ba:mka:r$'): 1})},
#    'straw': {"^i'b?adisini'joho:$": Counter({np.str_("^i'b?adisini'joho:$"): 1})},
#    'shelter': {"^'u:nu:'biri$": Counter({np.str_("^'u:nu:'biri$"): 1})},
#    'shoulder': {"^s?a'ga:bu$": Counter({np.str_("^s?a'ga:bu$"): 1})},
#    'lamb': {"^s?a'ga:bu$": Counter({np.str_("^s?a'ga:bu$"): 1})},
#    'carry': {"^s?a'ga:bu$": Counter({np.str_("^s?a'ga:bu$"): 1})},
#    'seated': {"^ame:'sas?e:$": Counter({np.str_("^ame:'sas?e:$"): 1})},
#    'footstep': {"^ka'dawme?ada'ma:suho:b$": Counter({np.str_("^ka'dawme?ada'ma:suho:b$"): 1})},
#    'fringe': {"^su:'fa:tho:j$": Counter({np.str_("^su:'fa:tho:j$"): 1})},
#    'bowl': {"^sallam'ta:jthe:bab'kantihob$": Counter({np.str_("^sallam'ta:jthe:bab'kantihob$"): 1})},
#    'blame': {"^samatta'ne:$": Counter({np.str_("^samatta'ne:$"): 1})},
#    'weapon': {"^e:ga'd?aje:na$": Counter({np.str_("^e:ga'd?aje:na$"): 1})},
#    'eld': {'^u:wingka$': Counter({np.str_('^u:wingka$'): 1})},
#    'loathe': {'^hima:ga:bu:j$': Counter({np.str_('^hima:ga:bu:j$'): 1})},
#    'misfortune': {'^salla:ma:he:b$': Counter({np.str_('^salla:ma:he:b$'): 1})},
#    'round': {'^kwada:da:t$': Counter({np.str_('^kwada:da:t$'): 1})},
#    'copper': {'^niha:si:s$': Counter({np.str_('^niha:si:s$'): 1})},
#    'nasty': {'^?ato:rbi:bu$': Counter({np.str_('^?ato:rbi:bu$'): 1})},
#    'unpleasant': {'^?ato:rbi:bu$': Counter({np.str_('^?ato:rbi:bu$'): 1})},
#    'imprison': {"^sidz'ni:b$": Counter({np.str_("^sidz'ni:b$"): 1})},
#    'prison': {'^tifir?ahe:baj$': Counter({np.str_('^tifir?ahe:baj$'): 1})},
#    'slave': {'^kisjawwa$': Counter({np.str_('^kisjawwa$'): 1})},
#    'treasure': {'^o:ma:lwa$': Counter({np.str_('^o:ma:lwa$'): 1})},
#    'suburb': {'^dawa:he:b$': Counter({np.str_('^dawa:he:b$'): 1})},
#    'vegetable': {'^ixada:ra:je:b$': Counter({np.str_('^ixada:ra:je:b$'): 1})},
#    'elderly': {'^e:girim$': Counter({np.str_('^e:girim$'): 1})},
#    'gossip': {'^wanas$': Counter({np.str_('^wanas$'): 1})},
#    'precede': {'^su:rte:naj$': Counter({np.str_('^su:rte:naj$'): 1})},
#    'itssurrounding': {'^?arjawwa$': Counter({np.str_('^?arjawwa$'): 1})},
#    'examine': {'^nisabbe:t$': Counter({np.str_('^nisabbe:t$'): 1})},
#    'kneel': {'^agnift$': Counter({np.str_('^agnift$'): 1})},
#    'overpass': {'^su:rnhe:b$': Counter({np.str_('^su:rnhe:b$'): 1})},
#    'audience': {'^faggade:d$': Counter({np.str_('^faggade:d$'): 1})},
#    'flapping': {'^halbo:ba?l$': Counter({np.str_('^halbo:ba?l$'): 1})},
#    'spite': {'^sakane:na:tika$': Counter({np.str_('^sakane:na:tika$'): 1})},
#    'girth': {'^tiga:ratiwwa$': Counter({np.str_('^tiga:ratiwwa$'): 1})},
#    'armpit': {'^ibaba:je:$': Counter({np.str_('^ibaba:je:$'): 1})},
#    'terrify': {'^nira:kwho:k$': Counter({np.str_('^nira:kwho:k$'): 1})},
#    'rent': {'^kira:j$': Counter({np.str_('^kira:j$'): 1})},
#    'neighbourhood': {'^tisawwe:tji$': Counter({np.str_('^tisawwe:tji$'): 1})},
#    'tall': {'^raga:ga$': Counter({np.str_('^raga:ga$'): 1})},
#    'unpaid': {'^wedha:j$': Counter({np.str_('^wedha:j$'): 1})},
#    'bill': {'^wedha:j$': Counter({np.str_('^wedha:j$'): 1})},
#    'information': {'^sakana:n$': Counter({np.str_('^sakana:n$'): 1})},
#    'borrow': {'^tisikwho:n$': Counter({np.str_('^tisikwho:n$'): 1})},
#    'miaow': {'^mia:w$': Counter({np.str_('^mia:w$'): 1})},
#    'souakin': {'^iso:kijo:hda$': Counter({np.str_('^iso:kijo:hda$'): 1})},
#    'few': {'^ji:na:t$': Counter({np.str_('^ji:na:t$'): 1})},
#    'state': {'^idama:ne$': Counter({np.str_('^idama:ne$'): 1})},
#    'describe': {'^wimitija:ti$': Counter({np.str_('^wimitija:ti$'): 1})},
#    'peace': {'^sallamja:nho:$': Counter({np.str_('^sallamja:nho:$'): 1})},
#    'abandon': {'^dadiban$': Counter({np.str_('^dadiban$'): 1})},
#    'pleased': {'^liba:ban$': Counter({np.str_('^liba:ban$'): 1})},
#    'traveller': {'^?i:ba:bkina$': Counter({np.str_('^?i:ba:bkina$'): 1})},
#    'breeder': {'^ims?arije:$': Counter({np.str_('^ims?arije:$'): 1})},
#    'deep': {'^ki:tkatta:m$': Counter({np.str_('^ki:tkatta:m$'): 1})},
#    'trace': {'^ttakatti$': Counter({np.str_('^ttakatti$'): 1})},
#    'plenty': {'^da:wri$': Counter({np.str_('^da:wri$'): 1})},
#    'clear': {'^kita:ba:jt$': Counter({np.str_('^kita:ba:jt$'): 1})},
#    'curve': {'^mhawaj$': Counter({np.str_('^mhawaj$'): 1})},
#    'shore': {'^mhalle:$': Counter({np.str_('^mhalle:$'): 1})},
#    'thread': {'^hasama:bi$': Counter({np.str_('^hasama:bi$'): 1})},
#    'human': {'^bahassejt$': Counter({np.str_('^bahassejt$'): 1})},
#    'being': {'^bahassejt$': Counter({np.str_('^bahassejt$'): 1})},
#    'gap': {'^faras(bi_517)ti$': Counter({np.str_('^faras(bi_517)ti$'): 1})},
#    'ablution': {'^gwada:mani$': Counter({np.str_('^gwada:mani$'): 1})},
#    'perform': {'^gwada:mani$': Counter({np.str_('^gwada:mani$'): 1})},
#    'stock': {'^addaji:g$': Counter({np.str_('^addaji:g$'): 1})},
#    'creep': {'^saffi:mtinihe:b$': Counter({np.str_('^saffi:mtinihe:b$'): 1})},
#    'gown': {'^gami:si:$': Counter({np.str_('^gami:si:$'): 1})},
#    'ugly': {'^amfirameja:$': Counter({np.str_('^amfirameja:$'): 1})},
#    'calm': {'^ru:gakatiki$': Counter({np.str_('^ru:gakatiki$'): 1})},
#    'deserted': {'^tigaba:ti$': Counter({np.str_('^tigaba:ti$'): 1})},
#    'champaign': {'^tigaba:ti$': Counter({np.str_('^tigaba:ti$'): 1})},
#    'bearing': {'^sajjasije:b$': Counter({np.str_('^sajjasije:b$'): 1})},
#    'wadi': {'^aba$': Counter({np.str_('^aba$'): 1})},
#    'impression': {'^jhandi$': Counter({np.str_('^jhandi$'): 1})},
#    'usual': {'^jhandi$': Counter({np.str_('^jhandi$'): 1})},
#    'flat': {'^bille:t$': Counter({np.str_('^bille:t$'): 1})},
#    'stare': {'^as@bbe:k$': Counter({np.str_('^as@bbe:k$'): 1})},
#    'arisen': {'^tifir?ije:b$': Counter({np.str_('^tifir?ije:b$'): 1})},
#    'snore': {'^massalant$': Counter({np.str_('^massalant$'): 1})},
#    'pretend': {'^massalant$': Counter({np.str_('^massalant$'): 1})},
#    'snoring': {'^tikantu:rte:b$': Counter({np.str_('^tikantu:rte:b$'): 1})},
#    'awake': {'^ikanthe:b$': Counter({np.str_('^ikanthe:b$'): 1})},
#    'several': {'^t?aba:wwa$': Counter({np.str_('^t?aba:wwa$'): 1})},
#    'danger': {'^xa:tarta$': Counter({np.str_('^xa:tarta$'): 1})},
#    'save': {'^sallamiho:g$': Counter({np.str_('^sallamiho:g$'): 1})},
#    'translator': {'^tardzima:l$': Counter({np.str_('^tardzima:l$'): 1})},
#    'ok': {'^da:jitu:$': Counter({np.str_('^da:jitu:$'): 1})},
#    'notice': {'^ba:s?aji:n$': Counter({np.str_('^ba:s?aji:n$'): 1})},
#    'bullet': {'^t@lga$': Counter({np.str_('^t@lga$'): 1})},
#    'shoot': {'^ad?i$': Counter({np.str_('^ad?i$'): 1})},
#    'disatnce': {'^me:sid$': Counter({np.str_('^me:sid$'): 1})},
#    'annual': {'^thawleja:j$': Counter({np.str_('^thawleja:j$'): 1})},
#    'cold': {'^m?akwara$': Counter({np.str_('^m?akwara$'): 1})},
#    'supply': {'^tibalamite:$': Counter({np.str_('^tibalamite:$'): 1})},
#    'thought': {'^hi:sja:t$': Counter({np.str_('^hi:sja:t$'): 1})},
#    'temper': {'^wininti:t$': Counter({np.str_('^wininti:t$'): 1})},
#    'assist': {'^hadri$': Counter({np.str_('^hadri$'): 1})},
#    'bore': {'^da:jagamenho$': Counter({np.str_('^da:jagamenho$'): 1})},
#    'repent': {'^bi:dije:$': Counter({np.str_('^bi:dije:$'): 1})},
#    'evil': {'^te:tmi:ge:$': Counter({np.str_('^te:tmi:ge:$'): 1})},
#    'policeman': {'^arawe:ja$': Counter({np.str_('^arawe:ja$'): 1})},
#    'intention': {'^nija:ju$': Counter({np.str_('^nija:ju$'): 1})},
#    'palm': {'^abtti:t$': Counter({np.str_('^abtti:t$'): 1})},
#    'ease': {'^whe:ri$': Counter({np.str_('^whe:ri$'): 1})},
#    'bless': {'^he:kwal$': Counter({np.str_('^he:kwal$'): 1})},
#    'holiness': {'^waljana:je:t$': Counter({np.str_('^waljana:je:t$'): 1})},
#    'crowd': {'^lamma:d$': Counter({np.str_('^lamma:d$'): 1})},
#    'lsee': {'^we?ajane:b$': Counter({np.str_('^we?ajane:b$'): 1})},
#    'roam': {'^di:no:tni$': Counter({np.str_('^di:no:tni$'): 1})},
#    'nearby': {'^dawili:$': Counter({np.str_('^dawili:$'): 1})},
#    'grind': {'^ifindzane:$': Counter({np.str_('^ifindzane:$'): 1})},
#    'improve': {'^isbo:ba:$': Counter({np.str_('^isbo:ba:$'): 1})},
#    'stitch': {'^tabjanit$': Counter({np.str_('^tabjanit$'): 1})},
#    'stuff': {'^jhakja:n$': Counter({np.str_('^jhakja:n$'): 1})},
#    'mmmmm': {'^mmmmm$': Counter({np.str_('^mmmmm$'): 1})},
#    'earthenware': {'^to:w?atiwa$': Counter({np.str_('^to:w?atiwa$'): 1})},
#    'grease': {'^whata:ji$': Counter({np.str_('^whata:ji$'): 1})},
#    'coat': {'^whata:ji$': Counter({np.str_('^whata:ji$'): 1})},
#    'overlook': {'^li:gamana:ti$': Counter({np.str_('^li:gamana:ti$'): 1})},
#    'flood': {'^i:ba:hassawu:k$': Counter({np.str_('^i:ba:hassawu:k$'): 1})},
#    'cross': {'^ibahassa$': Counter({np.str_('^ibahassa$'): 1})},
#    'flooding': {'^ibahassa$': Counter({np.str_('^ibahassa$'): 1})},
#    'trample': {'^e:tta:j$': Counter({np.str_('^e:tta:j$'): 1})},
#    'cemetery': {'^mi:masa:ji$': Counter({np.str_('^mi:masa:ji$'): 1})},
#    'filthy': {'^jhalakaje:$': Counter({np.str_('^jhalakaje:$'): 1})},
#    'remarry': {'^tiba:dinhe:bh$': Counter({np.str_('^tiba:dinhe:bh$'): 1})},
#    'divine': {'^w?idzru$': Counter({np.str_('^w?idzru$'): 1})},
#    'reward': {'^w?idzru$': Counter({np.str_('^w?idzru$'): 1})},
#    'rejoice': {'^afirhe:na$': Counter({np.str_('^afirhe:na$'): 1})},
#    'wear': {'^halakada$': Counter({np.str_('^halakada$'): 1})},
#    'qadi': {'^ga:d$': Counter({np.str_('^ga:d$'): 1})},
#    'famine': {'^madza?a:d$': Counter({np.str_('^madza?a:d$'): 1})},
#    'lap': {'^wawa:wja:nhob$': Counter({np.str_('^wawa:wja:nhob$'): 1})},
#    'nation': {'^w?isla:mi$': Counter({np.str_('^w?isla:mi$'): 1})},
#    'hunger': {'^hargwit$': Counter({np.str_('^hargwit$'): 1})},
#    'single': {'^ki:?is$': Counter({np.str_('^ki:?is$'): 1})},
#    'broken': {'^kat?ama$': Counter({np.str_('^kat?ama$'): 1})},
#    'gut': {'^amfari:d$': Counter({np.str_('^amfari:d$'): 1})},
#    'crying': {'^tiwa:wtit$': Counter({np.str_('^tiwa:wtit$'): 1})},
#    'possible': {'^ine:wa:b$': Counter({np.str_('^ine:wa:b$'): 1})},
#    'mention': {'^i:ktije:b$': Counter({np.str_('^i:ktije:b$'): 1})},
#    'dream': {'^jhaktane:b$': Counter({np.str_('^jhaktane:b$'): 1})},
#    'precious': {'^ja:gu:t$': Counter({np.str_('^ja:gu:t$'): 1})},
#    'deed': {'^tida:ji:ni:$': Counter({np.str_('^tida:ji:ni:$'): 1})},
#    'miserliness': {'^titi:birije:na:te:$': Counter({np.str_('^titi:birije:na:te:$'): 1})},
#    'low': {'^tidijja:tib$': Counter({np.str_('^tidijja:tib$'): 1})},
#    'swear': {'^hallalafo:jiho:b$': Counter({np.str_('^hallalafo:jiho:b$'): 1})},
#    'convince': {'^a:mansiho:b$': Counter({np.str_('^a:mansiho:b$'): 1})},
#    'asiste': {'^hadri$': Counter({np.str_('^hadri$'): 1})},
#    'wisdom': {'^sasu:ba:bt?a$': Counter({np.str_('^sasu:ba:bt?a$'): 1})},
#    'strongness': {'^?akirab$': Counter({np.str_('^?akirab$'): 1})},
#    'hitting': {'^o:t?awa$': Counter({np.str_('^o:t?awa$'): 1})},
#    'handle': {'^annu:ri:b$': Counter({np.str_('^annu:ri:b$'): 1})},
#    'soft': {'^in?akwnhom$': Counter({np.str_('^in?akwnhom$'): 1})},
#    'suffer': {'^angwarrha$': Counter({np.str_('^angwarrha$'): 1})},
#    'startled': {'^inafsi$': Counter({np.str_('^inafsi$'): 1})},
#    'killing': {'^madar$': Counter({np.str_('^madar$'): 1})},
#    'thirst': {'^titrame:n$': Counter({np.str_('^titrame:n$'): 1})},
#    'sharp': {'^w?akraka:b$': Counter({np.str_('^w?akraka:b$'): 1})},
#    'tamp': {'^haj?aju:kti:dikate$': Counter({np.str_('^haj?aju:kti:dikate$'): 1})},
#    'friendship': {'^rrha:takwo:$': Counter({np.str_('^rrha:takwo:$'): 1})},
#    'detestable': {'^nifirwa$': Counter({np.str_('^nifirwa$'): 1})},
#    'bastard': {'^whara:mdz?o:r$': Counter({np.str_('^whara:mdz?o:r$'): 1})},
#    'anthything': {'^ago:je:k$': Counter({np.str_('^ago:je:k$'): 1})},
#    'pierce': {'^tal?ame:ne:$': Counter({np.str_('^tal?ame:ne:$'): 1})},
#    'gulp': {'^dann?e:n$': Counter({np.str_('^dann?e:n$'): 1})},
#    'sip': {'^dann?e:n$': Counter({np.str_('^dann?e:n$'): 1})},
#    'split': {'^bho:t$': Counter({np.str_('^bho:t$'): 1})},
#    'edge': {'^igirma$': Counter({np.str_('^igirma$'): 1})},
#    'no': {'^kwa:k$': Counter({np.str_('^kwa:k$'): 1})},
#    'living': {'^idira:ro:$': Counter({np.str_('^idira:ro:$'): 1})},
#    'cutting': {'^itafsil$': Counter({np.str_('^itafsil$'): 1})},
#    'splash': {'^gwada:mibuj$': Counter({np.str_('^gwada:mibuj$'): 1})},
#    'previous': {'^t?afagirab$': Counter({np.str_('^t?afagirab$'): 1})},
#    'sheep': {'^t?anihe:na$': Counter({np.str_('^t?anihe:na$'): 1})},
#    'happyness': {'^ra:jhe:$': Counter({np.str_('^ra:jhe:$'): 1})},
#    'hafve': {'^ikatinho:b$': Counter({np.str_('^ikatinho:b$'): 1})},
#    'remuneration': {'^idzaza:jo:$': Counter({np.str_('^idzaza:jo:$'): 1})},
#    'wage': {'^idzaza:jo:$': Counter({np.str_('^idzaza:jo:$'): 1})},
#    'peep': {'^tal?ami:ne:$': Counter({np.str_('^tal?ami:ne:$'): 1})},
#    'sing': {'^kakafe:na$': Counter({np.str_('^kakafe:na$'): 1})},
#    'wolf': {'^a:me:tid?ane:n$': Counter({np.str_('^a:me:tid?ane:n$'): 1})},
#    'ancestor': {"^ho:'bu:ng$": Counter({np.str_("^ho:'bu:ng$"): 1})},
#    'means': {"^ta'ri:ge:t$": Counter({np.str_("^ta'ri:ge:t$"): 1})},
#    'scrutinize': {"^j?aj?a'si:t$": Counter({np.str_("^j?aj?a'si:t$"): 1})},
#    'forehead': {"^'sambi:be:n$": Counter({np.str_("^'sambi:be:n$"): 1})},
#    'course': {"^a'kira$": Counter({np.str_("^a'kira$"): 1})},
#    'owner': {"^an'kwana$": Counter({np.str_("^an'kwana$"): 1})},
#    'leaflet': {"^wal'le:ttan'?a:je:$": Counter({np.str_("^wal'le:ttan'?a:je:$"): 1})},
#    'weave': {"^simet'ti:t$": Counter({np.str_("^simet'ti:t$"): 1})},
#    'exhausted': {"^dijara'ne:k$": Counter({np.str_("^dijara'ne:k$"): 1})},
#    'ghost': {"^itfar?e'na$": Counter({np.str_("^itfar?e'na$"): 1})},
#    'creature': {"^ti'su:ki$": Counter({np.str_("^ti'su:ki$"): 1})},
#    'slipknot': {"^s?o:b'ja:thiwa$": Counter({np.str_("^s?o:b'ja:thiwa$"): 1})},
#    'bark': {"^kwinhatni'je:k$": Counter({np.str_("^kwinhatni'je:k$"): 1})},
#    'deliver': {'^farrije:w$': Counter({np.str_('^farrije:w$'): 1})},
#    'wipe': {'^hante:b$': Counter({np.str_('^hante:b$'): 1})},
#    'poison': {'^isamme$': Counter({np.str_('^isamme$'): 1})},
#    'smart': {'^habba:ri$': Counter({np.str_('^habba:ri$'): 1})},
#    'prefer': {'^she:sine:$': Counter({np.str_('^she:sine:$'): 1})},
#    'charity': {'^kara:ma:t$': Counter({np.str_('^kara:ma:t$'): 1})},
#    'compete': {'^ingwisirn$': Counter({np.str_('^ingwisirn$'): 1})},
#    'haleli': {'^whale:le$': Counter({np.str_('^whale:le$'): 1})},
#    'parallel': {'^imariwne:b$': Counter({np.str_('^imariwne:b$'): 1})},
#    'overtake': {'^hasami:ne:n$': Counter({np.str_('^hasami:ne:n$'): 1})},
#    'hidden': {'^id?ama:ne:$': Counter({np.str_('^id?ama:ne:$'): 1})},
#    'lizard': {'^tambal?aj$': Counter({np.str_('^tambal?aj$'): 1})},
#    'funeral': {'^idan?ete:na$': Counter({np.str_('^idan?ete:na$'): 1})},
#    'patient': {'^amtarra:mti:tka$': Counter({np.str_('^amtarra:mti:tka$'): 1})},
#    'nastiness': {'^nikte:ng$': Counter({np.str_('^nikte:ng$'): 1})},
#    'insulting': {'^ine:wa:jeb$': Counter({np.str_('^ine:wa:jeb$'): 1})},
#    'taste': {'^miri:ti:$': Counter({np.str_('^miri:ti:$'): 1})},
#    ...})}

# %%
dill.dump(merged_tes, open(merged_tes_path, 'wb'))
