# %%
import dill
import json
import string

import numpy as np
import scipy
import pandas as pd

import seaborn as sns

# %%
### UTIL
    
def clean(text):
    text = text.lower()
    text = text.encode("ascii", "ignore").decode("ascii")
    text = text.translate(str.maketrans('', '', string.punctuation))

    return text

# %%
processed_data_path = '../data/processed/'

corpus_narr_fn = processed_data_path + 'corpus_narr.pkl'
corpus_else_fn = processed_data_path + 'corpus_else.pkl'
fields_paths = processed_data_path + 'fields.pkl'

# %%
corpus_narr = dill.load(open(corpus_narr_fn, 'rb'))
corpus_else = dill.load(open(corpus_else_fn, 'rb'))
fields = dill.load(open(fields_paths, 'rb'))

# %%
len(fields)
# Out:
# 265

# %%
for f,l in fields:
    print(f)
# Out:
# ['remove' 'reach' 'arrive' 'come' 'leave' 'bring' 'get' 'take' 'carry']
# ['kill' 'beat' 'hit']
# ['beautiful' 'nice' 'good']
# ['say' 'do' 'become' 'happen' 'build' 'tell' 'make' 'speak' 'talk' 'put'
#  'story' 'call' 'language']
# ['start' 'begin' 'beginning']
# ['large' 'big' 'old' 'many' 'elder']
# ['man' 'child' 'guy' 'boy' 'son']
# ['take' 'catch' 'hold']
# ['ground' 'country' 'earth' 'land' 'world']
# ['today' 'day' 'time']
# ['day' 'tomorrow' 'morning']
# ['dead' 'die' 'kill']
# ['feel' 'hear' 'listen']
# ['little' 'small' 'young' 'few' 'son']
# ['see' 'look' 'watch' 'find']
# ['walk' 'go' 'pass']
# ['hear' 'know' 'understand']
# ['man' 'people' 'human' 'person']
# ['put' 'lay' 'lie']
# ['live' 'stay' 'sit' 'settle']
# ['marry' 'wedding' 'marriage']
# ['path' 'way' 'road']
# ['plan' 'think' 'thought']
# ['leave' 'stay' 'remain']
# ['fill' 'put']
# ['come' 'move']
# ['childhood' 'small']
# ['plant' 'planting']
# ['animal' 'hunt']
# ['mind' 'thought']
# ['shill' 'shilling']
# ['curse' 'scold']
# ['care' 'look']
# ['come' 'fall']
# ['dad' 'finished']
# ['hunger' 'hungry']
# ['bit' 'bite']
# ['find' 'get']
# ['adult' 'old']
# ['damage' 'hurt']
# ['arm' 'hand']
# ['become' 'turn']
# ['difficult' 'hard']
# ['mother' 'parent']
# ['care' 'wait']
# ['girl' 'sister']
# ['come' 'enter']
# ['expensive' 'price']
# ['death' 'die']
# ['disappear' 'lose']
# ['family' 'parent']
# ['get' 'live']
# ['dance' 'dancing']
# ['river' 'water']
# ['brother' 'friend']
# ['look' 'tell']
# ['heat' 'warm']
# ['grandchild' 'grandson']
# ['powerful' 'strong']
# ['doctor' 'healer']
# ['do' 'eat']
# ['sound' 'speak']
# ['bear' 'birth']
# ['mention' 'tell']
# ['go' 'put']
# ['fall' 'sick']
# ['become' 'way']
# ['chief' 'ruler']
# ['afternoon' 'evening']
# ['hunt' 'hunting']
# ['good' 'live']
# ['female' 'woman']
# ['bring' 'lie']
# ['life' 'live']
# ['fighting' 'war']
# ['love' 'pity']
# ['accept' 'agree']
# ['many' 'much']
# ['month' 'moon']
# ['town' 'village']
# ['lie' 'sleep']
# ['ravine' 'water']
# ['true' 'truth']
# ['young' 'youth']
# ['change' 'turn']
# ['hot' 'warm']
# ['know' 'remember']
# ['husband' 'man']
# ['bit' 'tell']
# ['drop' 'make']
# ['order' 'tell']
# ['notice' 'see']
# ['mom' 'mother']
# ['fall' 'go']
# ['brother' 'sister']
# ['language' 'word']
# ['history' 'story']
# ['afternoon' 'day']
# ['family' 'relative']
# ['need' 'want']
# ['call' 'name']
# ['poor' 'poverty']
# ['say' 'think']
# ['many' 'plenty']
# ['climb' 'go']
# ['alive' 'life']
# ['married' 'marry']
# ['tree' 'wood']
# ['little' 'place']
# ['cattle' 'cow']
# ['thing' 'way']
# ['keep' 'put']
# ['arrive' 'use']
# ['run' 'walk']
# ['write' 'writing']
# ['pray' 'prayer']
# ['chop' 'cut']
# ['heart' 'thought']
# ['chief' 'king']
# ['put' 'stand']
# ['see' 'show']
# ['cut' 'tear']
# ['buy' 'sell']
# ['time' 'want']
# ['go' 'move']
# ['bear' 'become']
# ['bad' 'wrong']
# ['say' 'today']
# ['place' 'put']
# ['anger' 'angry']
# ['rock' 'stone']
# ['learn' 'teach']
# ['brother' 'relative']
# ['chase' 'drive']
# ['pity' 'sorry']
# ['go' 'watch']
# ['look' 'take']
# ['cook' 'eat']
# ['bag' 'basket']
# ['fight' 'struggle']
# ['end' 'finish']
# ['chicken' 'hen']
# ['discuss' 'talk']
# ['home' 'village']
# ['ask' 'see']
# ['go' 'leave']
# ['custom' 'tradition']
# ['afraid' 'scared']
# ['red' 'reddish']
# ['quarrel' 'scold']
# ['carry' 'wear']
# ['elderly' 'old']
# ['do' 'finish']
# ['cook' 'prepare']
# ['branch' 'wood']
# ['sing' 'singe']
# ['fill' 'full']
# ['run' 'rush']
# ['give' 'put']
# ['cry' 'weep']
# ['little' 'story']
# ['look' 'search']
# ['explain' 'tell']
# ['people' 'town']
# ['drink' 'drunk']
# ['cause' 'make']
# ['big' 'great']
# ['leaf' 'leave']
# ['elder' 'parent']
# ['walk' 'wander']
# ['fall' 'sleep']
# ['baby' 'child']
# ['cap' 'hat']
# ['iron' 'metal']
# ['boil' 'prepare']
# ['fine' 'good']
# ['bad' 'ugly']
# ['come' 'return']
# ['day' 'daylight']
# ['ask' 'call']
# ['refuse' 'want']
# ['scream' 'shout']
# ['fish' 'fishing']
# ['cross' 'pass']
# ['bag' 'sack']
# ['bit' 'small']
# ['wife' 'woman']
# ['devil' 'evil']
# ['prepare' 'ready']
# ['husband' 'wife']
# ['get' 'heat']
# ['eye' 'source']
# ['feed' 'food']
# ['job' 'work']
# ['game' 'play']
# ['parent' 'people']
# ['angry' 'heart']
# ['afraid' 'frightened']
# ['bear' 'give']
# ['good' 'thing']
# ['bring' 'give']
# ['language' 'tongue']
# ['need' 'use']
# ['keep' 'stay']
# ['grandma' 'grandmother']
# ['bad' 'good']
# ['girl' 'woman']
# ['run' 'work']
# ['catch' 'grab']
# ['medicine' 'remedy']
# ['kill' 'slaughter']
# ['fall' 'throw']
# ['grow' 'stand']
# ['child' 'children']
# ['next' 'tomorrow']
# ['seat' 'sit']
# ['mother' 'woman']
# ['asleep' 'sleep']
# ['ceremony' 'custom']
# ['head' 'see']
# ['candle' 'fire']
# ['get' 'kill']
# ['find' 'meet']
# ['time' 'use']
# ['mean' 'take']
# ['enter' 'go']
# ['important' 'old']
# ['grateful' 'thank']
# ['disappear' 'go']
# ['dig' 'take']
# ['bear' 'produce']
# ['day' 'past']
# ['drink' 'eat']
# ['leave' 'throw']
# ['end' 'last']
# ['cow' 'meat']
# ['mother' 'mum']
# ['collect' 'gather']
# ['become' 'come']
# ['tell' 'warn']
# ['tomorrow' 'yesterday']
# ['look' 'seek']
# ['attach' 'tie']
# ['do' 'last']
# ['come' 'speak']
# ['brother' 'sibling']
# ['cut' 'leave']
# ['build' 'stop']
# ['fight' 'quarrel']
# ['grandfather' 'grandparent']
# ['go' 'return']
# ['happen' 'pass']
# ['evening' 'night']
# ['feed' 'give']
# ['call' 'use']
# ['love' 'want']
# ['pull' 'shoot']
# ['big' 'grow']
# ['say' 'want']
# ['marry' 'take']
# ['make' 'prepare']
# ['drop' 'throw']
# ['frighten' 'frightened']
# ['live' 'living']
# ['get' 'go']

# %%
### INDEPENDENT VARIABLES

def freq_field(field, lang, corpus, compute=False):
    if not compute:
        return 0
        
    count = 0
    total = 0

    
    for document in langcorp:
        for sentence in langcorp[document]:
            for word in langcorp[document][sentence]['spc']:
                total += 1
                if clean(word['lemma']) in field:
                    count += 1
    #print(count, '/', total, '=', count / total)
    if total == 0:
        return 0
    
    return count / total

# %%
### DEPENDENT VARIABLES

def h(X):
    p = lambda v: v / np.sum(X)
    return -np.sum([p(x) * np.log(p(x)) for x in X])

def measure_langfield_count(langfield):
    return len(langfield)

def measure_langfield_entropy(langfield):
    return h(list(langfield.values()))

# %%
### DATA TABLE

FREQS = pd.read_csv(processed_data_path + 'freqs.csv')

def populate_data(fields, corpus_narr, corpus_else, compute_freqs=True):
    d = {
        'field': list(),
        'lang': list(),
        'narr_freq': list(),
        'narr_freq_log': list(),
        'else_freq': list(), 
        'else_freq_log': list(),
        'lf_count' : list(),
        'lf_count_log': list(),
        'lf_entropy': list()
    }
    
    i = 0
    for field, langfields in fields:
        for lang in langfields:
            
            narr_freq = freq_field(field, corpus_narr[lang], compute_freqs)
            else_freq = freq_field(field, corpus_else[lang], compute_freqs)
            lf_count = measure_langfield_count(langfields[lang])
            lf_entropy = measure_langfield_entropy(langfields[lang])

            d['field'].append(field)
            d['lang'].append(lang)
            d['narr_freq'].append(narr_freq)
            d['narr_freq_log'].append(np.log(1 + narr_freq * 1e6))
            d['else_freq'].append(else_freq)
            d['else_freq_log'].append(np.log(1 + else_freq * 1e6))
            d['lf_count'].append(lf_count)
            d['lf_count_log'].append(np.log(lf_count + 1))
            d['lf_entropy'].append(lf_entropy)

        i+=1
        print(i, '/', len(fields))
        
    frame = pd.DataFrame(d)

    frame['narr_freq'] = FREQS.narr_freq
    frame['narr_freq_log'] = np.log(1 + frame.narr_freq * 1e6)
    frame['else_freq'] = FREQS.else_freq
    frame['else_freq_log'] = np.log(1 + frame.else_freq * 1e6)
# 189 / 265
# 190 / 265
# 191 / 265
# 192 / 265
# 193 / 265
# 194 / 265
# 195 / 265
# 196 / 265
# 197 / 265
# 198 / 265
# 199 / 265
# 200 / 265
# 201 / 265
# 202 / 265
# 203 / 265
# 204 / 265
# 205 / 265
# 206 / 265
# 207 / 265
# 208 / 265
# 209 / 265
# 210 / 265
# 211 / 265
# 212 / 265
# 213 / 265
# 214 / 265
# 215 / 265
# 216 / 265
# 217 / 265
# 218 / 265
# 219 / 265
# 220 / 265
# 221 / 265
# 222 / 265
# 223 / 265
# 224 / 265
# 225 / 265
# 226 / 265
# 227 / 265
# 228 / 265
# 229 / 265
# 230 / 265
# 231 / 265
# 232 / 265
# 233 / 265
# 234 / 265
# 235 / 265
# 236 / 265
# 237 / 265
# 238 / 265
# 239 / 265
# 240 / 265
# 241 / 265
# 242 / 265
# 243 / 265
# 244 / 265
# 245 / 265
# 246 / 265
# 247 / 265
# 248 / 265
# 249 / 265
# 250 / 265
# 251 / 265
# 252 / 265
# 253 / 265
# 254 / 265
# 255 / 265
# 256 / 265
# 257 / 265
# 258 / 265
# 259 / 265
# 260 / 265
# 261 / 265
# 262 / 265
# 263 / 265
# 264 / 265
# 265 / 265

# %%
# filter dataframe
data = df[(df.narr_freq != 0) & (df.else_freq != 0)]
data = data[data.lf_count != 0]

# %%
data
# Out:
#                                                    field      lang  narr_freq  \
# 2      [remove, reach, arrive, come, leave, bring, ge...  arap1274   0.010483
# 3      [remove, reach, arrive, come, leave, bring, ge...  bain1259   0.029076
# 5      [remove, reach, arrive, come, leave, bring, ge...  bora1263   0.019847
# 8      [remove, reach, arrive, come, leave, bring, ge...  dolg1241   0.015358
# 11     [remove, reach, arrive, come, leave, bring, ge...  goro1270   0.019721
# ...                                                  ...       ...        ...
# 12705                                          [get, go]  savo1255   0.020888
# 12708                                          [get, go]  sumi1235   0.002119
# 12713                                          [get, go]  trin1278   0.015274
# 12717                                          [get, go]  yong1270   0.007154
# 12718                                          [get, go]  yuca1254   0.006768
#
#        narr_freq_log  else_freq  else_freq_log  lf_count  lf_count_log  \
# 2           9.257636   0.010830       9.290198        54      4.007333
# 3          10.277701   0.024143      10.091797        51      3.951244
# 5           9.895877   0.015298       9.635546        98      4.595120
# 8           9.639487   0.019747       9.890832        44      3.806662
# 11          9.889482   0.011293       9.332040        57      4.060443
# ...              ...        ...            ...       ...           ...
# 12705       9.946965   0.008993       9.104291        11      2.484907
# 12708       7.659003   0.013572       9.515865        14      2.708050
# 12713       9.633979   0.028291      10.250326        24      3.218876
# 12717       8.875609   0.002598       7.862765        14      2.708050
# 12718       8.820137   0.015452       9.645537        12      2.564949
#
#        lf_entropy
# 2        3.275359
# 3        2.905421
# 5        3.679492
# 8        2.481308
# 11       3.504727
# ...           ...
# 12705    1.186050
# 12708    2.119316
# 12713    1.921186
# 12717    2.141620
# 12718    1.672619
#
# [3200 rows x 9 columns]

# %%
data.to_csv(processed_data_path + 'data.csv')
data[['field', 'lang', 'narr_freq', 'else_freq']].to_csv(processed_data_path + 'freqs.csv')
