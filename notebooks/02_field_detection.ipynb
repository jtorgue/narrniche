# %%
import dill
import json

import numpy as np
import scipy
import networkx as nx
import pandas as pd
import seaborn as sns

from collections import Counter
from scipy.sparse import csr_matrix

# %%
processed_data_path = '../data/processed/'

lexicon_fn = processed_data_path + 'lexicon.json'
tes_fn = processed_data_path + 'tes.pkl'
dirtes_fn = processed_data_path + 'dirtes.json'
colex_fn = processed_data_path + 'colex.pkl'
fields_fn = processed_data_path + 'fields.pkl'
merged_tes_fn = processed_data_path + 'merged_tes.pkl'
saturation_fn = processed_data_path + 'saturation.csv'

# %%
lexicon = json.load(open(lexicon_fn, 'r'))
tes = dill.load(open(tes_fn, 'rb'))
dirtes = json.load(open(dirtes_fn, 'r'))
colex = dill.load(open(colex_fn, 'rb'))
merged_tes = dill.load(open(merged_tes_fn, 'rb'))

# %%
### COLEX FUNCTIONS

def print_colex(lexicon, colex):
    rows = sorted(list(set(colex.nonzero()[0])))
    for i in rows:
        cols = colex.getrow(i).nonzero()[1]
        #print(i, cols)
        if len(cols) > 1:
            print(lexicon[i], ":", [(lexicon[j], int(colex[i,j])) for j in cols])

def filter_colex(colex, min_clx_count=None, max_clx_size=None):
    clx = colex.copy()
    
    # filter minimum colex count (min nlangs that colex)
    if min_clx_count:
        clx.data[clx.data < min_clx_count] = 0
        clx.eliminate_zeros()

    # filter maximum colex array size (max nterms in a row)
    if max_clx_size:
        larger = [i for i in set(clx.nonzero()[0]) if len(clx.getrow(i).nonzero()[1]) > max_clx_size]
        tmp = clx.toarray()
        tmp[larger, :] = 0
        tmp[:, larger] = 0

        clx = csr_matrix(tmp)
        clx.eliminate_zeros()
        
    return clx

# %%
### LEXICAL FIELDS

def idx2lex(lexicon, selected):
    return np.array(lexicon)[selected]

def lex2idx(lexicon, selected):
    return [lexicon.index(s) for s in selected]
    
def generate_arc_fields(colex):
    return list(map(list, set(map(tuple, map(sorted, zip(clx.nonzero()[0], clx.nonzero()[1]))))))

def generate_clique_fields(colex, k):
    g = nx.Graph(colex)
    return list(map(list, nx.community.k_clique_communities(g, k)))

def generate_arclic_fields(colex, k):
    arcs = generate_arc_fields(colex)
    cliques = generate_clique_fields(colex, k)
    
    isolated = list()

    for a in arcs:
        present = False
        for c in cliques:
            if a[0] in c and a[1] in c:
                present = True
                break
        if not present:
            isolated.append(a)
    
    return cliques + isolated

def expand_field(field, colex):
    return sorted(set(sum([list(colex[i].nonzero()[1]) for i in field], [])))

def term_count(langtes, term):
    count = 0
    for te in langtes:
        for stem in langtes[te]:
            if term in langtes[te][stem]:
                count += langtes[te][stem][term]
    return count

def structure_fields(fields, tes, lexicon, saturation_threshold=1.0):
    flds = list()
    sat = 0
    tot = 0
    for field in fields:
        field = idx2lex(lexicon, field)
        lf = dict()
        
        for lang in tes:
            lf[lang] = dict()
            tot += 1
            if saturation_ratio(field, tes[lang]) >= saturation_threshold:
                sat += 1
                lf[lang] = Counter([stem for seed in field if seed in tes[lang][0] for stem in tes[lang][0][seed]])
                #for seed in field:
                #    if seed in tes[lang][0]:
                #        for stem in tes[lang][0][seed]:
                #            lf[lang][stem] = len(tes[lang][0][seed][stem])
                    #if word in dirtes[lang]:
                    #    for term in dirtes[lang][word]:
                    #        lf[lang][term] = term_count(tes[lang][1], term)
        flds.append((field, lf))
    print("Obs:", sat, "/", tot)
    return flds

def saturation_ratio(field, langtes):
    count = 0
    for term in field:
        # add cleaning of langtes keys ?
        # change to dirtes ?
        if term in langtes[0]:
            count += 1
    return count / len(field)

def generate_saturation_dataframe(lexicon, fields, tes):
    saturation_df = pd.DataFrame(columns=['lang','field','ratio'])
    for lang in tes:
        langtes = tes[lang]
        for field in fields:
            field = idx2lex(lexicon, field)
            ratio = saturation_ratio(field, langtes)
            new_row = pd.DataFrame({"lang": [lang], "field": [field], "ratio": [ratio]})
            saturation_df = pd.concat([saturation_df, new_row], ignore_index=True)
    return saturation_df

# %%
### PARAMETERS
MIN_CLX_COUNT = 2
MAX_CLX_SIZE = 25
SATURATION_THRESHOLD = 1.0

# %%
clx = filter_colex(colex, MIN_CLX_COUNT, MAX_CLX_SIZE)

# %%
arcs = generate_arc_fields(clx)
for a in arcs:
    print(idx2lex(lexicon, a))

# %%
cliques = generate_clique_fields(clx, 3)
for c in cliques:
    print(idx2lex(lexicon, list(c)))

# %%
arclics = generate_arclic_fields(clx, 3)
for ac in arclics:
    print(idx2lex(lexicon, list(ac)))
# Out:
# ['remove' 'reach' 'arrive' 'come' 'leave' 'bring' 'get' 'take' 'carry']
# ['kill' 'beat' 'hit']
# ['beautiful' 'nice' 'good']
# ['say' 'do' 'become' 'happen' 'build' 'tell' 'make' 'speak' 'talk' 'put'
#  'story' 'call' 'language']
# ['start' 'begin' 'beginning']
# ['large' 'big' 'old' 'many' 'elder']
# ['man' 'child' 'guy' 'boy' 'son']
# ['take' 'catch' 'hold']
# ['ground' 'country' 'earth' 'land' 'world']
# ['today' 'day' 'time']
# ['day' 'tomorrow' 'morning']
# ['dead' 'die' 'kill']
# ['feel' 'hear' 'listen']
# ['little' 'small' 'young' 'few' 'son']
# ['see' 'look' 'watch' 'find']
# ['walk' 'go' 'pass']
# ['hear' 'know' 'understand']
# ['man' 'people' 'human' 'person']
# ['put' 'lay' 'lie']
# ['live' 'stay' 'sit' 'settle']
# ['marry' 'wedding' 'marriage']
# ['path' 'way' 'road']
# ['plan' 'think' 'thought']
# ['leave' 'stay' 'remain']
# ['fill' 'put']
# ['come' 'move']
# ['childhood' 'small']
# ['plant' 'planting']
# ['animal' 'hunt']
# ['mind' 'thought']
# ['shill' 'shilling']
# ['curse' 'scold']
# ['care' 'look']
# ['come' 'fall']
# ['dad' 'finished']
# ['hunger' 'hungry']
# ['bit' 'bite']
# ['find' 'get']
# ['adult' 'old']
# ['damage' 'hurt']
# ['arm' 'hand']
# ['become' 'turn']
# ['difficult' 'hard']
# ['mother' 'parent']
# ['care' 'wait']
# ['girl' 'sister']
# ['come' 'enter']
# ['expensive' 'price']
# ['death' 'die']
# ['disappear' 'lose']
# ['family' 'parent']
# ['get' 'live']
# ['dance' 'dancing']
# ['river' 'water']
# ['brother' 'friend']
# ['look' 'tell']
# ['heat' 'warm']
# ['grandchild' 'grandson']
# ['powerful' 'strong']
# ['doctor' 'healer']
# ['do' 'eat']
# ['sound' 'speak']
# ['bear' 'birth']
# ['mention' 'tell']
# ['go' 'put']
# ['fall' 'sick']
# ['become' 'way']
# ['chief' 'ruler']
# ['afternoon' 'evening']
# ['hunt' 'hunting']
# ['good' 'live']
# ['female' 'woman']
# ['bring' 'lie']
# ['life' 'live']
# ['fighting' 'war']
# ['love' 'pity']
# ['accept' 'agree']
# ['many' 'much']
# ['month' 'moon']
# ['town' 'village']
# ['lie' 'sleep']
# ['ravine' 'water']
# ['true' 'truth']
# ['young' 'youth']
# ['change' 'turn']
# ['hot' 'warm']
# ['know' 'remember']
# ['husband' 'man']
# ['bit' 'tell']
# ['drop' 'make']
# ['order' 'tell']
# ['notice' 'see']
# ['mom' 'mother']
# ['fall' 'go']
# ['brother' 'sister']
# ['language' 'word']
# ['history' 'story']
# ['afternoon' 'day']
# ['family' 'relative']
# ['need' 'want']
# ['call' 'name']
# ['poor' 'poverty']
# ['say' 'think']
# ['many' 'plenty']
# ['climb' 'go']
# ['alive' 'life']
# ['married' 'marry']
# ['tree' 'wood']
# ['little' 'place']
# ['cattle' 'cow']
# ['thing' 'way']
# ['keep' 'put']
# ['arrive' 'use']
# ['run' 'walk']
# ['write' 'writing']
# ['pray' 'prayer']
# ['chop' 'cut']
# ['heart' 'thought']
# ['chief' 'king']
# ['put' 'stand']
# ['see' 'show']
# ['cut' 'tear']
# ['buy' 'sell']
# ['time' 'want']
# ['go' 'move']
# ['bear' 'become']
# ['bad' 'wrong']
# ['say' 'today']
# ['place' 'put']
# ['anger' 'angry']
# ['rock' 'stone']
# ['learn' 'teach']
# ['brother' 'relative']
# ['chase' 'drive']
# ['pity' 'sorry']
# ['go' 'watch']
# ['look' 'take']
# ['cook' 'eat']
# ['bag' 'basket']
# ['fight' 'struggle']
# ['end' 'finish']
# ['chicken' 'hen']
# ['discuss' 'talk']
# ['home' 'village']
# ['ask' 'see']
# ['go' 'leave']
# ['custom' 'tradition']
# ['afraid' 'scared']
# ['red' 'reddish']
# ['quarrel' 'scold']
# ['carry' 'wear']
# ['elderly' 'old']
# ['do' 'finish']
# ['cook' 'prepare']
# ['branch' 'wood']
# ['sing' 'singe']
# ['fill' 'full']
# ['run' 'rush']
# ['give' 'put']
# ['cry' 'weep']
# ['little' 'story']
# ['look' 'search']
# ['explain' 'tell']
# ['people' 'town']
# ['drink' 'drunk']
# ['cause' 'make']
# ['big' 'great']
# ['leaf' 'leave']
# ['elder' 'parent']
# ['walk' 'wander']
# ['fall' 'sleep']
# ['baby' 'child']
# ['cap' 'hat']
# ['iron' 'metal']
# ['boil' 'prepare']
# ['fine' 'good']
# ['bad' 'ugly']
# ['come' 'return']
# ['day' 'daylight']
# ['ask' 'call']
# ['refuse' 'want']
# ['scream' 'shout']
# ['fish' 'fishing']
# ['cross' 'pass']
# ['bag' 'sack']
# ['bit' 'small']
# ['wife' 'woman']
# ['devil' 'evil']
# ['prepare' 'ready']
# ['husband' 'wife']
# ['get' 'heat']
# ['eye' 'source']
# ['feed' 'food']
# ['job' 'work']
# ['game' 'play']
# ['parent' 'people']
# ['angry' 'heart']
# ['afraid' 'frightened']
# ['bear' 'give']
# ['good' 'thing']
# ['bring' 'give']
# ['language' 'tongue']
# ['need' 'use']
# ['keep' 'stay']
# ['grandma' 'grandmother']
# ['bad' 'good']
# ['girl' 'woman']
# ['run' 'work']
# ['catch' 'grab']
# ['medicine' 'remedy']
# ['kill' 'slaughter']
# ['fall' 'throw']
# ['grow' 'stand']
# ['child' 'children']
# ['next' 'tomorrow']
# ['seat' 'sit']
# ['mother' 'woman']
# ['asleep' 'sleep']
# ['ceremony' 'custom']
# ['head' 'see']
# ['candle' 'fire']
# ['get' 'kill']
# ['find' 'meet']
# ['time' 'use']
# ['mean' 'take']
# ['enter' 'go']
# ['important' 'old']
# ['grateful' 'thank']
# ['disappear' 'go']
# ['dig' 'take']
# ['bear' 'produce']
# ['day' 'past']
# ['drink' 'eat']
# ['leave' 'throw']
# ['end' 'last']
# ['cow' 'meat']
# ['mother' 'mum']
# ['collect' 'gather']
# ['become' 'come']
# ['tell' 'warn']
# ['tomorrow' 'yesterday']
# ['look' 'seek']
# ['attach' 'tie']
# ['do' 'last']
# ['come' 'speak']
# ['brother' 'sibling']
# ['cut' 'leave']
# ['build' 'stop']
# ['fight' 'quarrel']
# ['grandfather' 'grandparent']
# ['go' 'return']
# ['happen' 'pass']
# ['evening' 'night']
# ['feed' 'give']
# ['call' 'use']
# ['love' 'want']
# ['pull' 'shoot']
# ['big' 'grow']
# ['say' 'want']
# ['marry' 'take']
# ['make' 'prepare']
# ['drop' 'throw']
# ['frighten' 'frightened']
# ['live' 'living']
# ['get' 'go']

# %%
len(arclics)
# Out:
# 265

# %%
fields = structure_fields(arclics, merged_tes, lexicon, SATURATION_THRESHOLD)
dill.dump(fields, open(fields_fn, 'wb'))
# Out:
# Obs: 7339 / 12720

# %%
saturation_df = generate_saturation_dataframe(lexicon, arclics, tes)
saturation_df.to_csv(saturation_fn)
saturation_df
# Out:
# /tmp/ipykernel_29965/109782161.py:86: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   saturation_df = pd.concat([saturation_df, new_row], ignore_index=True)
#            lang                                              field     ratio
# 0      anal1239  [remove, reach, arrive, come, leave, bring, ge...  0.888889
# 1      anal1239                                  [kill, beat, hit]  0.666667
# 2      anal1239                            [beautiful, nice, good]  1.000000
# 3      anal1239  [say, do, become, happen, build, tell, make, s...  0.923077
# 4      anal1239                          [start, begin, beginning]  1.000000
# ...         ...                                                ...       ...
# 12715  yura1255                                    [make, prepare]  0.500000
# 12716  yura1255                                      [drop, throw]  0.000000
# 12717  yura1255                             [frighten, frightened]  0.000000
# 12718  yura1255                                     [live, living]  1.000000
# 12719  yura1255                                          [get, go]  1.000000
#
# [12720 rows x 3 columns]

# %%
sns.histplot(saturation_df.ratio)
# Out:
# <Axes: xlabel='ratio', ylabel='Count'>

# %%
langs_per_field = pd.DataFrame({"field": [field[0] for field in fields], "nb_lang": [len([lang for lang in field[1] if len(field[1][lang]) > 0]) for field in fields]})
langs_per_field.to_csv(processed_data_path + 'langsxfield.csv')
langs_per_field.sort_values(by="nb_lang")
# Out:
#                   field  nb_lang
# 227   [grateful, thank]        3
# 148      [red, reddish]        3
# 30    [shill, shilling]        3
# 209  [medicine, remedy]        4
# 213   [child, children]        4
# ..                  ...      ...
# 221         [get, kill]       48
# 216     [mother, woman]       48
# 70         [good, live]       48
# 51          [get, live]       48
# 55         [look, tell]       48
#
# [265 rows x 2 columns]

# %%
avg_terms_per_field = pd.DataFrame({"lang": tes.keys(), "avg_terms_per_field": [np.mean([len(field[1][lang]) for field in fields]) for lang in tes]})
avg_terms_per_field.to_csv(processed_data_path + 'avg_terms_per_field.csv')
avg_terms_per_field.sort_values(by="avg_terms_per_field", ascending=False)
#sns.barplot(data=avg_terms_per_field, x="lang", y="avg_terms_per_field")
# Out:
#         lang  avg_terms_per_field
# 5   bora1263            13.445283
# 18  komn1238            11.913208
# 15  kaka1265            11.022642
# 4   beja1238             9.720755
# 0   anal1239             9.230189
# 3   bain1259             8.373585
# 2   arap1274             8.101887
# 41  trin1278             7.886792
# 11  goro1270             7.109434
# 8   dolg1241             7.105660
# 34  sout2856             7.094340
# 7   cash1254             7.041509
# 37  svan1243             6.830189
# 1   apah1238             6.656604
# 16  kama1351             6.637736
# 17  kark1256             6.562264
# 45  yong1270             6.264151
# 43  urum1249             6.218868
# 30  ruul1235             5.935849
# 42  tsim1256             5.788679
# 32  sanz1248             5.781132
# 9   even1259             5.724528
# 20  movi1243             5.596226
# 31  sadu1234             5.486792
# 22  nisv1234             5.335849
# 25  nort2875             5.105660
# 27  pnar1238             5.037736
# 23  nngg1234             4.992453
# 14  jeju1234             4.792453
# 44  vera1241             4.547170
# 26  orko1234             4.294340
# 24  nort2641             4.241509
# 12  hoch1243             4.196226
# 46  yuca1254             4.045283
# 10  goem1240             3.992453
# 40  texi1237             3.898113
# 39  teop1238             3.735849
# 28  port1286             3.267925
# 38  taba1259             3.169811
# 19  lowe1385             3.124528
# 29  resi1247             2.950943
# 36  sumi1235             2.698113
# 6   cabe1245             2.400000
# 33  savo1255             2.396226
# 13  jeha1242             2.249057
# 35  sout3282             1.849057
# 47  yura1255             1.826415
# 21  ngal1292             1.766038

# %%
# COUNTING MERGED STEM
merged_tes['beja1238'][1]['land' ]

for seed in merged_tes['beja1238'][0]:
    for stem in merged_tes['beja1238'][0][seed]:
        if 'ha:s' in stem:
            print(stem, seed)

# %%
field = {'ground', 'earth', 'land', 'country', 'world'}
lang = 'beja1238'

Counter([stem for seed in select if seed in merged_tes[lang][0] for stem in tes[lang][0][seed]])
