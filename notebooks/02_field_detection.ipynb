# %%
import dill
import json

import numpy as np
import scipy
import networkx as nx
import pandas as pd
import seaborn as sns

from collections import Counter
from scipy.sparse import csr_matrix

# %%
processed_data_path = '../data/processed/'

lexicon_fn = processed_data_path + 'lexicon.json'
tes_fn = processed_data_path + 'tes.pkl'
dirtes_fn = processed_data_path + 'dirtes.json'
colex_fn = processed_data_path + 'colex.pkl'
fields_fn = processed_data_path + 'fields.pkl'
merged_tes_fn = processed_data_path + 'merged_tes.pkl'
saturation_fn = processed_data_path + 'saturation.csv'

# %%
lexicon = json.load(open(lexicon_fn, 'r'))
tes = dill.load(open(tes_fn, 'rb'))
dirtes = json.load(open(dirtes_fn, 'r'))
colex = dill.load(open(colex_fn, 'rb'))
merged_tes = dill.load(open(merged_tes_fn, 'rb'))

# %%
### COLEX FUNCTIONS

def print_colex(lexicon, colex):
    rows = sorted(list(set(colex.nonzero()[0])))
    for i in rows:
        cols = colex.getrow(i).nonzero()[1]
        #print(i, cols)
        if len(cols) > 1:
            print(lexicon[i], ":", [(lexicon[j], int(colex[i,j])) for j in cols])

def filter_colex(colex, min_clx_count=None, max_clx_size=None):
    clx = colex.copy()
    
    # filter minimum colex count (min nlangs that colex)
    if min_clx_count:
        clx.data[clx.data < min_clx_count] = 0
        clx.eliminate_zeros()

    # filter maximum colex array size (max nterms in a row)
    if max_clx_size:
        larger = [i for i in set(clx.nonzero()[0]) if len(clx.getrow(i).nonzero()[1]) > max_clx_size]
        tmp = clx.toarray()
        tmp[larger, :] = 0
        tmp[:, larger] = 0

        clx = csr_matrix(tmp)
        clx.eliminate_zeros()
        
    return clx

# %%
### LEXICAL FIELDS

def idx2lex(lexicon, selected):
    return np.array(lexicon)[selected]

def lex2idx(lexicon, selected):
    return [lexicon.index(s) for s in selected]
    
def generate_arc_fields(colex):
    return list(map(list, set(map(tuple, map(sorted, zip(clx.nonzero()[0], clx.nonzero()[1]))))))

def generate_clique_fields(colex, k):
    g = nx.Graph(colex)
    return list(map(list, nx.community.k_clique_communities(g, k)))

def generate_arclic_fields(colex, k):
    arcs = generate_arc_fields(colex)
    cliques = generate_clique_fields(colex, k)
    
    isolated = list()

    for a in arcs:
        present = False
        for c in cliques:
            if a[0] in c and a[1] in c:
                present = True
                break
        if not present:
            isolated.append(a)
    
    return cliques + isolated

# obsolete
def expand_field(field, colex):
    return sorted(set(sum([list(colex[i].nonzero()[1]) for i in field], [])))

# obsolete
def term_count(langtes, term):
    count = 0
    for te in langtes:
        for stem in langtes[te]:
            if term in langtes[te][stem]:
                count += langtes[te][stem][term]
    return count

def structure_fields(fields, tes, lexicon, saturation_threshold=1.0):
    flds = list()
    sat = 0
    tot = 0
    for field in fields:
        field = idx2lex(lexicon, field)
        lf = dict()
        
        for lang in tes:
            lf[lang] = dict()
            tot += 1
            if saturation_ratio(field, tes[lang]) >= saturation_threshold:
                sat += 1
                #lf[lang] = Counter([stem for seed in field if seed in tes[lang][0] for stem in tes[lang][0][seed]])

                # get stems & their counts for field in lang
                stems = dict()
                for seed in field:
                    if seed in tes[lang][0]:
                        for stem in tes[lang][0][seed]:
                            if stem in stems:
                                stems[stem] += len(tes[lang][0][seed][stem])
                            else:
                                stems[stem] = len(tes[lang][0][seed][stem])

                # remove stems with count=1
                lf[lang] = {s: c for s, c in stems.items() if c > 1}
                
            if lang == 'beja1238':
                print(field, lf[lang])
        flds.append((field, lf))
    print("Obs:", sat, "/", tot)
    return flds

def saturation_ratio(field, langtes):
    count = 0
    for term in field:
        # add cleaning of langtes keys ?
        # change to dirtes ?
        if term in langtes[0]:
            count += 1
    return count / len(field)

def generate_saturation_dataframe(lexicon, fields, tes):
    saturation_df = pd.DataFrame(columns=['lang','field','ratio'])
    for lang in tes:
        langtes = tes[lang]
        for field in fields:
            field = idx2lex(lexicon, field)
            ratio = saturation_ratio(field, langtes)
            new_row = pd.DataFrame({"lang": [lang], "field": [field], "ratio": [ratio]})
            saturation_df = pd.concat([saturation_df, new_row], ignore_index=True)
    return saturation_df

# %%
### PARAMETERS
MIN_CLX_COUNT = 2
MAX_CLX_SIZE = 25
SATURATION_THRESHOLD = 1.0

# %%
clx = filter_colex(colex, MIN_CLX_COUNT, MAX_CLX_SIZE)

# %%
arcs = generate_arc_fields(clx)
for a in arcs:
    print(idx2lex(lexicon, a))

# %%
cliques = generate_clique_fields(clx, 3)
for c in cliques:
    print(idx2lex(lexicon, list(c)))

# %%
arclics = generate_arclic_fields(clx, 3)
for ac in arclics:
    print(idx2lex(lexicon, list(ac)))
# Out:
# ['remove' 'reach' 'arrive' 'come' 'leave' 'bring' 'get' 'take' 'carry']
# ['kill' 'beat' 'hit']
# ['beautiful' 'nice' 'good']
# ['say' 'do' 'become' 'happen' 'build' 'tell' 'make' 'speak' 'talk' 'put'
#  'story' 'call' 'language']
# ['start' 'begin' 'beginning']
# ['large' 'big' 'old' 'many' 'elder']
# ['man' 'child' 'guy' 'boy' 'son']
# ['take' 'catch' 'hold']
# ['ground' 'country' 'earth' 'land' 'world']
# ['today' 'day' 'time']
# ['day' 'tomorrow' 'morning']
# ['dead' 'die' 'kill']
# ['feel' 'hear' 'listen']
# ['little' 'small' 'young' 'few' 'son']
# ['see' 'look' 'watch' 'find']
# ['walk' 'go' 'pass']
# ['hear' 'know' 'understand']
# ['man' 'people' 'human' 'person']
# ['put' 'lay' 'lie']
# ['live' 'stay' 'sit' 'settle']
# ['marry' 'wedding' 'marriage']
# ['path' 'way' 'road']
# ['plan' 'think' 'thought']
# ['leave' 'stay' 'remain']
# ['fill' 'put']
# ['come' 'move']
# ['childhood' 'small']
# ['plant' 'planting']
# ['animal' 'hunt']
# ['mind' 'thought']
# ['shill' 'shilling']
# ['curse' 'scold']
# ['care' 'look']
# ['come' 'fall']
# ['dad' 'finished']
# ['hunger' 'hungry']
# ['bit' 'bite']
# ['find' 'get']
# ['adult' 'old']
# ['damage' 'hurt']
# ['arm' 'hand']
# ['become' 'turn']
# ['difficult' 'hard']
# ['mother' 'parent']
# ['care' 'wait']
# ['girl' 'sister']
# ['come' 'enter']
# ['expensive' 'price']
# ['death' 'die']
# ['disappear' 'lose']
# ['family' 'parent']
# ['get' 'live']
# ['dance' 'dancing']
# ['river' 'water']
# ['brother' 'friend']
# ['look' 'tell']
# ['heat' 'warm']
# ['grandchild' 'grandson']
# ['powerful' 'strong']
# ['doctor' 'healer']
# ['do' 'eat']
# ['sound' 'speak']
# ['bear' 'birth']
# ['mention' 'tell']
# ['go' 'put']
# ['fall' 'sick']
# ['become' 'way']
# ['chief' 'ruler']
# ['afternoon' 'evening']
# ['hunt' 'hunting']
# ['good' 'live']
# ['female' 'woman']
# ['bring' 'lie']
# ['life' 'live']
# ['fighting' 'war']
# ['love' 'pity']
# ['accept' 'agree']
# ['many' 'much']
# ['month' 'moon']
# ['town' 'village']
# ['lie' 'sleep']
# ['ravine' 'water']
# ['true' 'truth']
# ['young' 'youth']
# ['change' 'turn']
# ['hot' 'warm']
# ['know' 'remember']
# ['husband' 'man']
# ['bit' 'tell']
# ['drop' 'make']
# ['order' 'tell']
# ['notice' 'see']
# ['mom' 'mother']
# ['fall' 'go']
# ['brother' 'sister']
# ['language' 'word']
# ['history' 'story']
# ['afternoon' 'day']
# ['family' 'relative']
# ['need' 'want']
# ['call' 'name']
# ['poor' 'poverty']
# ['say' 'think']
# ['many' 'plenty']
# ['climb' 'go']
# ['alive' 'life']
# ['married' 'marry']
# ['tree' 'wood']
# ['little' 'place']
# ['cattle' 'cow']
# ['thing' 'way']
# ['keep' 'put']
# ['arrive' 'use']
# ['run' 'walk']
# ['write' 'writing']
# ['pray' 'prayer']
# ['chop' 'cut']
# ['heart' 'thought']
# ['chief' 'king']
# ['put' 'stand']
# ['see' 'show']
# ['cut' 'tear']
# ['buy' 'sell']
# ['time' 'want']
# ['go' 'move']
# ['bear' 'become']
# ['bad' 'wrong']
# ['say' 'today']
# ['place' 'put']
# ['anger' 'angry']
# ['rock' 'stone']
# ['learn' 'teach']
# ['brother' 'relative']
# ['chase' 'drive']
# ['pity' 'sorry']
# ['go' 'watch']
# ['look' 'take']
# ['cook' 'eat']
# ['bag' 'basket']
# ['fight' 'struggle']
# ['end' 'finish']
# ['chicken' 'hen']
# ['discuss' 'talk']
# ['home' 'village']
# ['ask' 'see']
# ['go' 'leave']
# ['custom' 'tradition']
# ['afraid' 'scared']
# ['red' 'reddish']
# ['quarrel' 'scold']
# ['carry' 'wear']
# ['elderly' 'old']
# ['do' 'finish']
# ['cook' 'prepare']
# ['branch' 'wood']
# ['sing' 'singe']
# ['fill' 'full']
# ['run' 'rush']
# ['give' 'put']
# ['cry' 'weep']
# ['little' 'story']
# ['look' 'search']
# ['explain' 'tell']
# ['people' 'town']
# ['drink' 'drunk']
# ['cause' 'make']
# ['big' 'great']
# ['leaf' 'leave']
# ['elder' 'parent']
# ['walk' 'wander']
# ['fall' 'sleep']
# ['baby' 'child']
# ['cap' 'hat']
# ['iron' 'metal']
# ['boil' 'prepare']
# ['fine' 'good']
# ['bad' 'ugly']
# ['come' 'return']
# ['day' 'daylight']
# ['ask' 'call']
# ['refuse' 'want']
# ['scream' 'shout']
# ['fish' 'fishing']
# ['cross' 'pass']
# ['bag' 'sack']
# ['bit' 'small']
# ['wife' 'woman']
# ['devil' 'evil']
# ['prepare' 'ready']
# ['husband' 'wife']
# ['get' 'heat']
# ['eye' 'source']
# ['feed' 'food']
# ['job' 'work']
# ['game' 'play']
# ['parent' 'people']
# ['angry' 'heart']
# ['afraid' 'frightened']
# ['bear' 'give']
# ['good' 'thing']
# ['bring' 'give']
# ['language' 'tongue']
# ['need' 'use']
# ['keep' 'stay']
# ['grandma' 'grandmother']
# ['bad' 'good']
# ['girl' 'woman']
# ['run' 'work']
# ['catch' 'grab']
# ['medicine' 'remedy']
# ['kill' 'slaughter']
# ['fall' 'throw']
# ['grow' 'stand']
# ['child' 'children']
# ['next' 'tomorrow']
# ['seat' 'sit']
# ['mother' 'woman']
# ['asleep' 'sleep']
# ['ceremony' 'custom']
# ['head' 'see']
# ['candle' 'fire']
# ['get' 'kill']
# ['find' 'meet']
# ['time' 'use']
# ['mean' 'take']
# ['enter' 'go']
# ['important' 'old']
# ['grateful' 'thank']
# ['disappear' 'go']
# ['dig' 'take']
# ['bear' 'produce']
# ['day' 'past']
# ['drink' 'eat']
# ['leave' 'throw']
# ['end' 'last']
# ['cow' 'meat']
# ['mother' 'mum']
# ['collect' 'gather']
# ['become' 'come']
# ['tell' 'warn']
# ['tomorrow' 'yesterday']
# ['look' 'seek']
# ['attach' 'tie']
# ['do' 'last']
# ['come' 'speak']
# ['brother' 'sibling']
# ['cut' 'leave']
# ['build' 'stop']
# ['fight' 'quarrel']
# ['grandfather' 'grandparent']
# ['go' 'return']
# ['happen' 'pass']
# ['evening' 'night']
# ['feed' 'give']
# ['call' 'use']
# ['love' 'want']
# ['pull' 'shoot']
# ['big' 'grow']
# ['say' 'want']
# ['marry' 'take']
# ['make' 'prepare']
# ['drop' 'throw']
# ['frighten' 'frightened']
# ['live' 'living']
# ['get' 'go']

# %%
len(arclics[3])

# %%
len(arclics)

# %%
fields = structure_fields(arclics, merged_tes, lexicon, SATURATION_THRESHOLD)
dill.dump(fields, open(fields_fn, 'wb'))
# Out:
# ['remove' 'reach' 'arrive' 'come' 'leave' 'bring' 'get' 'take' 'carry'] {}
# ['kill' 'beat' 'hit'] {'^dera:': 2, 'di': 40, '^gale:l': 3, '^t?ati$': 2, ':t?a': 4, 'int?': 3, '^tab?a': 3}
# ['beautiful' 'nice' 'good'] {'wr': 13, 'sikwa:n': 2, '^da:j': 22, 'bo:b': 3, '^fagar': 2, 'a:ja$': 2, 'ska': 2}
# ['say' 'do' 'become' 'happen' 'build' 'tell' 'make' 'speak' 'talk' 'put'
#  'story' 'call' 'language'] {}
# ['start' 'begin' 'beginning'] {}
# ['large' 'big' 'old' 'many' 'elder'] {}
# ['man' 'child' 'guy' 'boy' 'son'] {'tak': 255, ':nd': 48, '^da$': 10, '?ar': 58, '^?o:r': 4, "^j?a'r": 2, '^?ar$': 3, '?o:r': 49, "?a'r": 4, '?are:': 4}
# ['take' 'catch' 'hold'] {'ks': 22, 'abik': 24, '^ah': 17, 'sallama': 8, 'ni:n': 7, 'ambi:k': 5, 'fir?a': 6, '^ta:wti:t$': 3, 'fit': 4, '^tendije:k$': 2, "^a'hi:t$": 2, '^nu:nam': 2, 'ha:jt$': 2, 'he:n': 3, 'alak': 3, "^o:'": 2, 'kja': 2, 'r?i$': 2, '?a:b': 2, "'m": 2, 'agwi:gw': 3, '^tu:si:ne:n$': 2, 'lha:g': 2, '^j?abikna$': 2, '^ims?ab': 2, 'ke:b': 2, 'w?abko:': 7}
# ['ground' 'country' 'earth' 'land' 'world'] {'ha:s': 26, '^bal': 4, '^wha:s': 4, '^tigadi:ri$': 2, '^ist?': 2, '^tidijj': 3}
# ['today' 'day' 'time'] {'^ams': 10, 'ams': 19, 'ji:n': 11, 'b?e': 6, '^lh': 7, 'dama': 3, '^be:tej$': 2, '^b?ik': 2, 'ka$': 38, 'do:r': 32, 'ama:n': 7, 'mru:k$': 2, 'riwhe': 2, ':tk$': 2, "sa'": 2, 'ke:$': 2}
# ['day' 'tomorrow' 'morning'] {'ams': 19, 'ji:n': 9, 'b?e': 6, '^lh': 7, 'dama': 3, '^be:tej$': 2, '^b?ik': 2, 'lhajt': 7, '^lhe': 2, 'fadzil': 15, ':mha': 10, '^?a:wi:': 2, '^mhe:t': 2, '^wan': 2}
# ['dead' 'die' 'kill'] {'^aja:': 7, '^dira:b$': 2, '^rhitne:$': 2, '^firha': 2, '^i:j': 2, '^dera:': 2, 'di': 40}
# ['feel' 'hear' 'listen'] {'siw': 12, 'ma:s': 2, '^isine:': 4}
# ['little' 'small' 'young' 'few' 'son'] {'dabal': 13, '^adam': 5, 'mirb': 3, '^ada:mina:jd$': 2, 'hankwil': 2, '?o:r': 22, "?a'r": 4, '?are:': 4, '?ar': 6}
# ['see' 'look' 'watch' 'find'] {'rh': 91, 'bib': 6, 'sib': 26, 'sambi:b': 11, 'har': 16, "'ha": 4, 'rare': 3, 'it?i$': 2, "'rha$": 2, '^biddi': 2, 'i:ti:$': 2, 'gw?ad': 3, '^sann': 22, 'mar': 46, 'sin': 18, '^isa:n': 6, '^e:tni': 6, 'ime:r': 4, '^mer': 3, 'sanho:k': 3, 'ise:n': 3, '^imi:rn': 2, 'na:w': 2, 'nna$': 2}
# ['walk' 'go' 'pass'] {'re:r': 40, '^be:ti:': 16, '^e:b': 20, 'baj': 17, '?ag': 12, 'su:m': 10, 'tikw': 11, 'hasam': 8, 'r?': 17, 'gi:g': 14, '^imo:ra': 4, '^iwara': 4, '^aba:j': 3, 'be:nho:': 3, '^re:w': 4, "^'dha:j": 3, '^ne': 4, 'gar': 4, 'u:g': 3, 'idha': 3, 'tho:': 3, 'di': 7, '^j?': 10, 'has': 8, '^do:ra': 3}
# ['hear' 'know' 'understand'] {'siw': 12, 'ma:s': 2, 'kt': 31, 'ka:ka': 9, 'gi:m': 7, 'gam': 9, 'binka:n': 4, 'kan': 6, "^ak'te:": 2, 'kan$': 2}
# ['man' 'people' 'human' 'person'] {'tak': 255, ':nd': 48, '^da$': 10, '?ar': 6, 'dhe:j': 63, '^id?ama': 2, '^wali:ka$': 2, 'iski:na': 2, '^ammarr': 2}
# ['put' 'lay' 'lie'] {}
# ['live' 'stay' 'sit' 'settle'] {'^aski': 12, '^mitija': 2, ':st?': 5, '^s?at': 2, 's?': 20}
# ['marry' 'wedding' 'marriage'] {'d?ir': 17, 'do:ba': 9}
# ['path' 'way' 'road'] {'darab': 3, '^darbi$': 2, 'haj?a': 7, '^isikka:j$': 5, '^abadan$': 4, 'rne:b': 2, '^t?i:te:t$': 3, 'kka:j$': 10}
# ['plan' 'think' 'thought'] {}
# ['leave' 'stay' 'remain'] {'gi:g': 55, 'ndi:f': 10, '?is': 11, '^isti$': 6, '^whidz$': 3, 'diwo': 2, 'ie:': 2, 'sa:b': 3, '^itfar?': 2, 'alla:j': 2, 'arim': 2, '^misi$': 2, '^akaje:$': 2, 'di': 33, ':st?': 5, '^s?at': 2, 'as?e': 2}
# ['fill' 'put'] {'bti:t$': 2, '^gw?as': 2, '^da:s': 37, 'd?': 27, 'dann?': 6, 'sj': 2}
# ['come' 'move'] {'^j?': 130, '^e:ja': 23, '^e:ti': 8, '?e:': 16, '^u:mha$': 5, '^e:nan': 3, 'the:b$': 5, 'ba?': 3, '?o:ri$': 3, ':si:n': 3, '^?i': 4, 'e:tn': 3, 'tije:b$': 3, 'adz': 3, 'hanta': 8, '^be:rs': 3, '^e:b': 3, '^sang': 2}
# ['childhood' 'small'] {}
# ['plant' 'planting'] {}
# ['animal' 'hunt'] {"^jhaja'": 3, "^tidha'ni:ni$": 2, '^sa:ki': 4, 'sikn': 3}
# ['mind' 'thought'] {}
# ['shill' 'shilling'] {}
# ['curse' 'scold'] {}
# ['care' 'look'] {'^aba:ki$': 2, 'sib': 26, 'sambi:b': 11, 'har': 16, "'ha": 4, 'rare': 3, 'it?i$': 2, "'rha$": 2, '^biddi': 2, 'i:ti:$': 2}
# ['come' 'fall'] {'^j?': 130, '^e:ja': 23, '^e:ti': 8, '?e:': 16, '^u:mha$': 5, '^e:nan': 3, 'the:b$': 5, 'ba?': 3, '?o:ri$': 3, ':si:n': 3, '^?i': 4, 'e:tn': 3, 'tije:b$': 3, 'adz': 3, '^dib': 27, '^diwi': 2}
# ['dad' 'finished'] {}
# ['hunger' 'hungry'] {'haragw': 4}
# ['bit' 'bite'] {}
# ['find' 'get'] {'^sann': 22, 'mar': 46, 'sin': 18, '^isa:n': 6, '^e:tni': 6, 'ime:r': 4, '^mer': 3, 'sanho:k': 3, 'ise:n': 3, '^imi:rn': 2, 'na:w': 2, 'nna$': 2, '^itambi:l$': 3, '^afir?a': 3, '^timir': 3, 'takwa:k': 2, 'dangar$': 2, '^i:biri': 3, 'tifir?a': 2, 'hak': 17}
# ['adult' 'old'] {}
# ['damage' 'hurt'] {}
# ['arm' 'hand'] {'?aji$': 2, '?aj': 20, '^so:b': 3}
# ['become' 'turn'] {'ke': 31, 'rawe:sa': 8, 'ikat': 13, '^aka:': 6, 'anki:re': 3, '^aslim': 3, '?ak': 4, 'i:kt': 4, '^aki$': 2, '^e:tmi:': 2, 'e:ji$': 2, '^idama:n$': 2, '^so:d': 2, '^gu:d': 2, '^lhi:': 2, 'iktij': 2, 'i:dh': 2, '^lew': 2, '^do:ro:': 2, 'wawa:w': 2, '^u:do:r$': 2}
# ['difficult' 'hard'] {}
# ['mother' 'parent'] {}
# ['care' 'wait'] {'^aba:ki$': 2, 'git': 9, '^hangi:': 4, 'hag': 3, '^nd': 2, 'sin$': 2}
# ['girl' 'sister'] {}
# ['come' 'enter'] {'^j?': 130, '^e:ja': 23, '^e:ti': 8, '?e:': 16, '^u:mha$': 5, '^e:nan': 3, 'the:b$': 5, 'ba?': 3, '?o:ri$': 3, ':si:n': 3, '^?i': 4, 'e:tn': 3, 'tije:b$': 3, 'adz': 3, 'su:m': 7}
# ['expensive' 'price'] {}
# ['death' 'die'] {'^t?ati$': 2, '^rhitne:$': 2, '^firha': 2, '^i:j': 2}
# ['disappear' 'lose'] {'kwid': 8, '^dej?ame:$': 2, '^garab$': 2}
# ['family' 'parent'] {}
# ['get' 'live'] {'^itambi:l$': 3, '^afir?a': 3, '^timir': 3, 'takwa:k': 2, 'dangar$': 2, '^i:biri': 3, 'tifir?a': 2, 'hak': 17, '^aski': 12, '^mitija': 2}
# ['dance' 'dancing'] {}
# ['river' 'water'] {'jam': 41}
# ['brother' 'friend'] {'sana': 5, 'raw': 39, '^w?ara': 2}
# ['look' 'tell'] {'sib': 26, 'sambi:b': 11, 'har': 16, "'ha": 4, 'rare': 3, 'it?i$': 2, "'rha$": 2, '^biddi': 2, 'i:ti:$': 2, 'he:b': 49, 'hadi': 10, 'ndiho:k': 4, 'so:j': 5, "ab'kini": 3, '^deja': 4, '^aj': 9, 'ho:n$': 5, 'he:m$': 3, '^e:ne:ti$': 2, '^amfar': 2, 'tijo': 3, ':gid': 2, ':no:k': 2, 'inhe:': 2, ':dn': 6}
# ['heat' 'warm'] {}
# ['grandchild' 'grandson'] {}
# ['powerful' 'strong'] {'kira': 5, 'akir': 11, 'anki': 4}
# ['doctor' 'healer'] {}
# ['do' 'eat'] {'sak': 21, 'id?': 10, 'go:je:': 3, '^rhisa': 3, 'war': 5, '^ba:we:ri:nhe:b$': 2, '^ho:k$': 3, '^i:wr': 2, 'saga:m': 3, 'tido:': 2, '^d?i:t$': 2, 'a:ja$': 2, '^e:dna$': 2, '^ki:k': 2, 'tam': 45, '^a:m': 3, '^?a:me': 2}
# ['sound' 'speak'] {}
# ['bear' 'birth'] {'^firi:t$': 2}
# ['mention' 'tell'] {'he:b': 49, 'hadi': 10, 'ndiho:k': 4, 'so:j': 5, "ab'kini": 3, '^deja': 4, '^aj': 9, 'ho:n$': 5, 'he:m$': 3, '^e:ne:ti$': 2, '^amfar': 2, 'tijo': 3, ':gid': 2, ':no:k': 2, 'inhe:': 2, ':dn': 6}
# ['go' 'put'] {'^be:ti:': 16, '^e:b': 20, 'baj': 17, '?ag': 12, 'su:m': 10, 'tikw': 11, 'hasam': 8, 'r?': 17, 'gi:g': 14, '^imo:ra': 4, '^iwara': 4, '^aba:j': 3, 'be:nho:': 3, '^re:w': 4, "^'dha:j": 3, '^ne': 4, 'gar': 4, 'u:g': 3, 'idha': 3, 'tho:': 3, 'di': 7, '^j?': 10, '^da:s': 37, 'd?': 27, 'dann?': 6, 'sj': 2}
# ['fall' 'sick'] {}
# ['become' 'way'] {'ke': 31, 'rawe:sa': 8, 'ikat': 13, '^aka:': 6, 'anki:re': 3, '^aslim': 3, '?ak': 4, 'i:kt': 4, '^aki$': 2, '^e:tmi:': 2, 'e:ji$': 2, '^idama:n$': 2, '^so:d': 2, '^gu:d': 2, '^lhi:': 2, 'iktij': 2, 'i:dh': 2, 'haj?a': 7, '^isikka:j$': 5, '^abadan$': 4, 'rne:b': 2, '^t?i:te:t$': 3}
# ['chief' 'ruler'] {}
# ['afternoon' 'evening'] {'^hamni:': 2, '^w?i:sa:jo:$': 3, 'girab$': 3}
# ['hunt' 'hunting'] {'^sa:ki': 7, 'sikn': 3}
# ['good' 'live'] {'^da:j': 22, 'bo:b': 3, '^fagar': 2, 'a:ja$': 2, 'ska': 2, '^aski': 12, '^mitija': 2}
# ['female' 'woman'] {'^kwa:t$': 2, 'ad?a': 15, 'm?a$': 12, 'tak': 48}
# ['bring' 'lie'] {'^ha:j': 45, '^hi:': 7, ':ne:$': 4, '^tisto:': 2, '^j?': 5, '^b?': 13, '^gwisir': 2}
# ['life' 'live'] {'^l?a:': 3, '^w?amrijo:k$': 2, '^aski': 12, '^mitija': 2}
# ['fighting' 'war'] {}
# ['love' 'pity'] {'^esse': 2, '^are:j': 2}
# ['accept' 'agree'] {'diba': 3, 'fag': 3}
# ['many' 'much'] {'^na:ka:$': 2}
# ['month' 'moon'] {}
# ['town' 'village'] {'madi:na': 2, 'halla': 3}
# ['lie' 'sleep'] {'^b?': 13, '^gwisir': 2, '^diw': 11, '^na:j': 5}
# ['ravine' 'water'] {}
# ['true' 'truth'] {}
# ['young' 'youth'] {}
# ['change' 'turn'] {'^gajja': 2, '^lew': 2, '^do:ro:': 2, 'wawa:w': 2, '^u:do:r$': 2}
# ['hot' 'warm'] {}
# ['know' 'remember'] {'kt': 31, 'ka:ka': 9, 'gi:m': 7, 'gam': 9, 'binka:n': 4, 'kan': 6, "^ak'te:": 2}
# ['husband' 'man'] {'^itak': 2, 'tak': 255, ':nd': 48, '^da$': 10, '?ar': 6}
# ['bit' 'tell'] {'he:b': 49, 'hadi': 10, 'ndiho:k': 4, 'so:j': 5, "ab'kini": 3, '^deja': 4, '^aj': 9, 'ho:n$': 5, 'he:m$': 3, '^e:ne:ti$': 2, '^amfar': 2, 'tijo': 3, ':gid': 2, ':no:k': 2, 'inhe:': 2, ':dn': 6}
# ['drop' 'make'] {'^d?i:t$': 2, 'idha': 2, '^kad': 7, 'se': 17, 'd?i': 12, '^dzaban': 4, 'w?ajiso': 3, 'isja:n': 3, 'ikwa:s': 3, 'tar': 5, '^dann?e': 4, 'stin': 3, '^gadabisinho:k$': 2, 'tikwikw': 2, 'sangad': 2, "w't": 2, 'si:n': 3, 'ma:s': 2, 'jho:b$': 2, 'a:jo:': 2, 'wu:': 2, 'tid$': 2, '^na:n$': 2}
# ['order' 'tell'] {}
# ['notice' 'see'] {'rh': 91, 'bib': 3}
# ['mom' 'mother'] {}
# ['fall' 'go'] {'^dib': 27, '^diwi': 2, '^be:ti:': 16, '^e:b': 20, 'baj': 17, '?ag': 12, 'su:m': 10, 'tikw': 11, 'hasam': 8, 'r?': 17, 'gi:g': 14, '^imo:ra': 4, '^iwara': 4, '^aba:j': 3, 'be:nho:': 3, '^re:w': 4, "^'dha:j": 3, '^ne': 4, 'gar': 4, 'u:g': 3, 'idha': 3, 'tho:': 3, 'di': 7, '^j?': 10}
# ['brother' 'sister'] {}
# ['language' 'word'] {'bhali': 3, 'bhal': 12, '^j?ad': 7}
# ['history' 'story'] {}
# ['afternoon' 'day'] {'^hamni:': 2, 'ams': 19, 'ji:n': 9, 'b?e': 6, '^lh': 7, 'dama': 3, '^be:tej$': 2, '^b?ik': 2}
# ['family' 'relative'] {'ndiwa': 6, '^aja': 3, '^j?ajid': 2}
# ['need' 'want'] {'ka:b': 2, 'dije:': 5, 'we:na': 3, '^ijad$': 2, '^and': 4, '^saga:ma$': 2, '^di:t$': 3, '^arawe': 2, '^tama': 2, "^'a": 2, 'i:d': 6}
# ['call' 'name'] {'ali:': 18, 'dne': 12, '^da:jije:b$': 2, '^e:ne:?$': 2, '^ni:d': 2, 'sma': 6, '^i:dn': 4, '^sim': 2}
# ['poor' 'poverty'] {'miski:n': 13}
# ['say' 'think'] {'e:n$': 456, 'di': 296, 'in': 126, ':dn': 33, 'ne:$': 41, '^ti:': 13, 'i:d': 12, '^hi:s': 20, 'jjas': 6}
# ['many' 'plenty'] {'^na:ka:$': 2}
# ['climb' 'go'] {'^re:': 5, '^be:ti:': 16, '^e:b': 20, 'baj': 17, '?ag': 12, 'su:m': 10, 'tikw': 11, 'hasam': 8, 'r?': 17, 'gi:g': 14, '^imo:ra': 4, '^iwara': 4, '^aba:j': 3, 'be:nho:': 3, '^re:w': 4, "^'dha:j": 3, '^ne': 4, 'gar': 4, 'u:g': 3, 'idha': 3, 'tho:': 3, 'di': 7, '^j?': 10}
# ['alive' 'life'] {'^l?a:': 3}
# ['married' 'marry'] {'d?ir': 19}
# ['tree' 'wood'] {'handi': 25}
# ['little' 'place'] {'dabal': 2, 'mhi:n': 80, 'jam': 9, ':jida$': 3, '^mhin': 2}
# ['cattle' 'cow'] {'re:w': 11, 's?a': 5}
# ['thing' 'way'] {'^na': 28, ':na$': 20, '^tina:t': 5, '^to:n$': 3, 'tu:n': 4, 'te:na:t': 3, 'we:naka': 2, '^to:na:$': 2, 'haj?a': 7, '^isikka:j$': 5, '^abadan$': 4, 'rne:b': 2, '^t?i:te:t$': 3}
# ['keep' 'put'] {'^ake:t': 4, 'na:same': 2, '^hus$': 2, '^da:s': 37, 'd?': 27, 'dann?': 6, 'sj': 2}
# ['arrive' 'use'] {'ti:m': 5, 'timn': 5, ':jida$': 3, 'kitim': 2, '^j?ij': 2, '^e:jam$': 4, '^nid?i': 3, '^harro:': 2, '^askin': 2, '^hawa:': 2, '^b?i': 2, 'asti$': 2}
# ['run' 'walk'] {'^da:b': 45, "^da:'be": 6, "^'da:be:$": 2, 'far': 7, 're:r': 40}
# ['write' 'writing'] {}
# ['pray' 'prayer'] {'si:le:l': 4, '^w?i:sa:jo:$': 3, '^da:jije:b$': 2}
# ['chop' 'cut'] {}
# ['heart' 'thought'] {'gin?i': 2}
# ['chief' 'king'] {'had?a': 9, 'mali': 11}
# ['put' 'stand'] {'^da:s': 37, 'd?': 27, 'dann?': 6, 'sj': 2, '^?asti$': 6, '^ga:lkaka$': 2, 'ingidi': 2}
# ['see' 'show'] {'rh': 91, 'bib': 3, 'rhis': 18}
# ['cut' 'tear'] {'^fassa': 5, '^to:jaj$': 5, 'kat?': 3}
# ['buy' 'sell'] {'e:jn': 5, 'lib': 7, 'na:th': 2, 'he:na$': 2, 'kagi:gj': 2}
# ['time' 'want'] {'ka$': 38, 'do:r': 32, 'ama:n': 7, 'mru:k$': 2, 'riwhe': 2, ':tk$': 2, "sa'": 2, 'ke:$': 2, 'ji:n': 2, 'dije:': 5, 'we:na': 3, '^ijad$': 2, '^and': 4, '^saga:ma$': 2, '^di:t$': 3, '^arawe': 2, '^tama': 2, "^'a": 2, 'i:d': 6}
# ['go' 'move'] {'^be:ti:': 16, '^e:b': 23, 'baj': 17, '?ag': 12, 'su:m': 10, 'tikw': 11, 'hasam': 8, 'r?': 17, 'gi:g': 14, '^imo:ra': 4, '^iwara': 4, '^aba:j': 3, 'be:nho:': 3, '^re:w': 4, "^'dha:j": 3, '^ne': 4, 'gar': 4, 'u:g': 3, 'idha': 3, 'tho:': 3, 'di': 7, '^j?': 10, 'hanta': 8, '^be:rs': 3, '^sang': 2}
# ['bear' 'become'] {'ke': 31, 'rawe:sa': 8, 'ikat': 13, '^aka:': 6, 'anki:re': 3, '^aslim': 3, '?ak': 4, 'i:kt': 4, '^aki$': 2, '^e:tmi:': 2, 'e:ji$': 2, '^idama:n$': 2, '^so:d': 2, '^gu:d': 2, '^lhi:': 2, 'iktij': 2, 'i:dh': 2}
# ['bad' 'wrong'] {'ma:g': 7, '^e:tmi:': 2, 'lo:k': 2}
# ['say' 'today'] {'e:n$': 456, 'di': 296, 'in': 126, ':dn': 33, 'ne:$': 41, '^ti:': 13, 'i:d': 12, '^ams': 10}
# ['place' 'put'] {'mhi:n': 80, 'jam': 9, ':jida$': 3, '^mhin': 2, '^da:s': 37, 'd?': 27, 'dann?': 6, 'sj': 2}
# ['anger' 'angry'] {}
# ['rock' 'stone'] {'?aw': 13, '^li:l': 2, '^ho:so:$': 2}
# ['learn' 'teach'] {}
# ['brother' 'relative'] {'sana': 5, '^aja': 3, '^j?ajid': 2}
# ['chase' 'drive'] {'gale': 6, '^sikwi': 2, '^sankw': 2}
# ['pity' 'sorry'] {}
# ['go' 'watch'] {'^be:ti:': 16, '^e:b': 20, 'baj': 17, '?ag': 12, 'su:m': 10, 'tikw': 11, 'hasam': 8, 'r?': 17, 'gi:g': 14, '^imo:ra': 4, '^iwara': 4, '^aba:j': 3, 'be:nho:': 3, '^re:w': 4, "^'dha:j": 3, '^ne': 4, 'gar': 4, 'u:g': 3, 'idha': 3, 'tho:': 3, 'di': 7, '^j?': 10, 'gw?ad': 3, 'bib': 3}
# ['look' 'take'] {'sib': 26, 'sambi:b': 11, 'har': 16, "'ha": 4, 'rare': 3, 'it?i$': 2, "'rha$": 2, '^biddi': 2, 'i:ti:$': 2, 'ks': 22, 'abik': 24, '^ah': 17, 'sallama': 8, 'ni:n': 7, 'ambi:k': 5, 'fir?a': 6, '^ta:wti:t$': 3, 'fit': 4, '^tendije:k$': 2, "^a'hi:t$": 2, '^nu:nam': 2, 'ha:jt$': 2, 'he:n': 3, 'alak': 3, "^o:'": 2, 'kja': 2, 'r?i$': 2, '?a:b': 2, "'m": 2}
# ['cook' 'eat'] {'tikwij': 6, '^binka:': 2, 'tam': 45, '^a:m': 3, '^?a:me': 2}
# ['bag' 'basket'] {'gid$': 6}
# ['fight' 'struggle'] {}
# ['end' 'finish'] {'xaro:$': 2, 'ni:wa': 2, '^fa:j': 8, '^b?': 6, 'nhad': 3}
# ['chicken' 'hen'] {}
# ['discuss' 'talk'] {}
# ['home' 'village'] {'halla': 3}
# ['ask' 'see'] {'akana': 11, '^ra:te:': 2, 'rh': 91, 'bib': 3}
# ['go' 'leave'] {'^be:ti:': 16, '^e:b': 20, 'baj': 17, '?ag': 12, 'su:m': 10, 'tikw': 11, 'hasam': 8, 'r?': 17, 'gi:g': 69, '^imo:ra': 4, '^iwara': 4, '^aba:j': 3, 'be:nho:': 3, '^re:w': 4, "^'dha:j": 3, '^ne': 4, 'gar': 4, 'u:g': 3, 'idha': 3, 'tho:': 3, 'di': 40, '^j?': 10, 'ndi:f': 10, '?is': 11, '^isti$': 6, '^whidz$': 3, 'diwo': 2, 'ie:': 2, 'sa:b': 3, '^itfar?': 2, 'alla:j': 2, 'arim': 2, '^misi$': 2, '^akaje:$': 2}
# ['custom' 'tradition'] {}
# ['afraid' 'scared'] {}
# ['red' 'reddish'] {}
# ['quarrel' 'scold'] {}
# ['carry' 'wear'] {}
# ['elderly' 'old'] {'ad?a': 15, 'e:girim': 5, 'dama': 3, 's?i': 3}
# ['do' 'finish'] {'sak': 21, 'id?': 10, 'go:je:': 3, '^rhisa': 3, 'war': 5, '^ba:we:ri:nhe:b$': 2, '^ho:k$': 3, '^i:wr': 2, 'saga:m': 3, 'tido:': 2, '^d?i:t$': 2, 'a:ja$': 2, '^e:dna$': 2, '^ki:k': 2, '^fa:j': 8, '^b?': 6, 'nhad': 3}
# ['cook' 'prepare'] {'tikwij': 6, '^binka:': 2, 'bisira': 4}
# ['branch' 'wood'] {'handi': 11}
# ['sing' 'singe'] {}
# ['fill' 'full'] {'bti:t$': 2, '^gw?as': 2, '^gab': 6, 'ata:b': 4, '^gwida$': 2}
# ['run' 'rush'] {}
# ['give' 'put'] {':w': 38, 'he:b': 27, 'niw': 9, 'kara:ma': 7, '^hi:': 9, '^sal': 7, '^hija': 3, '^iw$': 3, '^he': 5, '^gw?as': 3, 'ri:t$': 3, "hi:'": 2, 'kte:b$': 2, 'jaw': 2, '^tifir?': 2, '^nh': 2, '^da:s': 37, 'd?': 27, 'dann?': 6, 'sj': 2}
# ['cry' 'weep'] {'^wa:w': 9, 'wa:w': 5}
# ['little' 'story'] {'dabal': 2, 'gis': 3, 'ba:b$': 3}
# ['look' 'search'] {'sib': 26, 'sambi:b': 11, 'har': 16, "'ha": 4, 'rare': 3, 'it?i$': 2, "'rha$": 2, '^biddi': 2, 'i:ti:$': 2}
# ['explain' 'tell'] {'tija': 3, 'he:b': 49, 'hadi': 10, 'ndiho:k': 4, 'so:j': 5, "ab'kini": 3, '^deja': 4, '^aj': 9, 'ho:n$': 5, 'he:m$': 3, '^e:ne:ti$': 2, '^amfar': 2, 'tijo': 3, ':gid': 2, ':no:k': 2, 'inhe:': 2, ':dn': 6}
# ['people' 'town'] {'dhe:j': 63, '^id?ama': 2, '^wali:ka$': 2, 'iski:na': 2, '^ammarr': 2, 'madi:na': 2}
# ['drink' 'drunk'] {'gw?': 36, '^gw?': 5}
# ['cause' 'make'] {}
# ['big' 'great'] {'ddigi': 5, '^akira$': 2}
# ['leaf' 'leave'] {}
# ['elder' 'parent'] {}
# ['walk' 'wander'] {'re:r': 40, '^ha:d': 3, 'no:j': 3}
# ['fall' 'sleep'] {'^dib': 27, '^diwi': 2, '^diw': 11, '^na:j': 5}
# ['baby' 'child'] {'jna$': 2, '?ar': 40, '^?o:r': 4, "^j?a'r": 2}
# ['cap' 'hat'] {}
# ['iron' 'metal'] {}
# ['boil' 'prepare'] {}
# ['fine' 'good'] {'da:ji': 11, '^kwati:': 2, '^da:j': 22, 'bo:b': 3, '^fagar': 2, 'a:ja$': 2, 'ska': 2}
# ['bad' 'ugly'] {'ma:g': 7, '^e:tmi:': 2}
# ['come' 'return'] {}
# ['day' 'daylight'] {}
# ['ask' 'call'] {'akana': 11, '^ra:te:': 2, 'ali:': 18, 'dne': 12, '^da:jije:b$': 2, '^e:ne:?$': 2, '^ni:d': 2}
# ['refuse' 'want'] {'hab': 4, 'irri:b': 3, 'ribna': 2, 'dije:': 5, 'we:na': 3, '^ijad$': 2, '^and': 4, '^saga:ma$': 2, '^di:t$': 3, '^arawe': 2, '^tama': 2, "^'a": 2, 'i:d': 6}
# ['scream' 'shout'] {'gami:': 3, '^wali:k': 3, 'kwinh': 2}
# ['fish' 'fishing'] {}
# ['cross' 'pass'] {'has': 8, '^do:ra': 3}
# ['bag' 'sack'] {}
# ['bit' 'small'] {'dabal': 11}
# ['wife' 'woman'] {'taka': 27, 'ad?a': 15, 'm?a$': 12, 'tak': 48}
# ['devil' 'evil'] {"^si:'ta:n$": 3}
# ['prepare' 'ready'] {'bisira': 4}
# ['husband' 'wife'] {'^itak': 2, '^kinamdad?ar$': 2, 'taka': 27}
# ['get' 'heat'] {}
# ['eye' 'source'] {}
# ['feed' 'food'] {'^kalla:': 4, '^d?o:r': 4, 'm?ari': 16}
# ['job' 'work'] {'^dadib': 3, 'saga': 35, 'sanh': 8}
# ['game' 'play'] {'^hawa': 12}
# ['parent' 'people'] {}
# ['angry' 'heart'] {'^gadabisinho:k$': 2, 'gin?i': 2}
# ['afraid' 'frightened'] {'rkw': 7, '^ri': 2}
# ['bear' 'give'] {':w': 38, 'he:b': 27, 'niw': 9, 'kara:ma': 7, '^hi:': 9, '^sal': 7, '^hija': 3, '^iw$': 3, '^he': 5, '^gw?as': 3, 'ri:t$': 3, "hi:'": 2, 'kte:b$': 2, 'jaw': 2, '^tifir?': 2, '^nh': 2}
# ['good' 'thing'] {'^da:j': 22, 'bo:b': 3, '^fagar': 2, 'a:ja$': 2, 'ska': 2, '^na': 28, ':na$': 20, '^tina:t': 5, '^to:n$': 3, 'tu:n': 4, 'te:na:t': 3, 'we:naka': 2, '^to:na:$': 2}
# ['bring' 'give'] {'^ha:j': 45, '^hi:': 16, ':ne:$': 4, '^tisto:': 2, '^j?': 5, ':w': 38, 'he:b': 27, 'niw': 9, 'kara:ma': 7, '^sal': 7, '^hija': 3, '^iw$': 3, '^he': 5, '^gw?as': 3, 'ri:t$': 3, "hi:'": 2, 'kte:b$': 2, 'jaw': 2, '^tifir?': 2, '^nh': 2}
# ['language' 'tongue'] {'bhali': 3}
# ['need' 'use'] {'ka:b': 2, '^nid?i': 3, '^harro:': 2, '^askin': 2, '^e:jam$': 2, '^hawa:': 2, '^b?i': 2, 'asti$': 2}
# ['keep' 'stay'] {'^ake:t': 4, 'na:same': 2, '^hus$': 2, ':st?': 5, '^s?at': 2}
# ['grandma' 'grandmother'] {}
# ['bad' 'good'] {'ma:g': 7, '^e:tmi:': 2, '^da:j': 22, 'bo:b': 3, '^fagar': 2, 'a:ja$': 2, 'ska': 2}
# ['girl' 'woman'] {'^t?o:r': 12, '?o:t': 6, '^t?ar': 6, '^?ari': 2, 'ad?a': 15, 'm?a$': 12, 'tak': 48}
# ['run' 'work'] {'^da:b': 45, "^da:'be": 6, "^'da:be:$": 2, 'far': 7, 'saga': 35, 'sanh': 8}
# ['catch' 'grab'] {'agwi:gw': 3, '^tu:si:ne:n$': 2, 'lha:g': 2, '^j?abikna$': 2, '^ims?ab': 2, 'ke:b': 2, '^abk': 2}
# ['medicine' 'remedy'] {}
# ['kill' 'slaughter'] {'^dera:': 2, 'di': 40, 'har': 14}
# ['fall' 'throw'] {'^dib': 27, '^diwi': 2, 'ngi': 15, 'gid': 12, 'ho:so:$': 3, 'ha:s$': 2}
# ['grow' 'stand'] {'fu:l': 2, '^?asti$': 6, '^ga:lkaka$': 2, 'ingidi': 2}
# ['child' 'children'] {}
# ['next' 'tomorrow'] {'^am?': 2, 'lhajt': 7, '^lhe': 2}
# ['seat' 'sit'] {':st?': 2, 's?': 20}
# ['mother' 'woman'] {'de:t': 13, '^tu:nd': 8, 'ndije:t': 2, 'ad?a': 15, 'm?a$': 12, 'tak': 48}
# ['asleep' 'sleep'] {'diw': 9, '^diw': 11, '^na:j': 5}
# ['ceremony' 'custom'] {}
# ['head' 'see'] {'girm': 12, '^thu:mande:ti$': 2, 'rh': 91, 'bib': 3}
# ['candle' 'fire'] {}
# ['get' 'kill'] {'^itambi:l$': 3, '^afir?a': 3, '^timir': 3, 'takwa:k': 2, 'dangar$': 2, '^i:biri': 3, 'tifir?a': 2, 'hak': 17, '^dera:': 2, 'di': 40}
# ['find' 'meet'] {'^sann': 22, 'mar': 46, 'sin': 18, '^isa:n': 6, '^e:tni': 6, 'ime:r': 4, '^mer': 3, 'sanho:k': 3, 'ise:n': 3, '^imi:rn': 2, 'na:w': 2, 'nna$': 2, 'sisn': 8, '^sanni': 3, '^kir': 2, 'isinh': 2}
# ['time' 'use'] {'ka$': 38, 'do:r': 32, 'ama:n': 7, 'mru:k$': 2, 'riwhe': 2, ':tk$': 2, "sa'": 2, 'ke:$': 2, 'ji:n': 2, '^nid?i': 3, '^harro:': 2, '^askin': 2, '^e:jam$': 2, '^hawa:': 2, '^b?i': 2, 'asti$': 2}
# ['mean' 'take'] {'^gin': 6, '^lawa$': 2, 'ks': 22, 'abik': 24, '^ah': 17, 'sallama': 8, 'ni:n': 7, 'ambi:k': 5, 'fir?a': 6, '^ta:wti:t$': 3, 'fit': 4, '^tendije:k$': 2, "^a'hi:t$": 2, '^nu:nam': 2, 'ha:jt$': 2, 'he:n': 3, 'alak': 3, "^o:'": 2, 'kja': 2, 'r?i$': 2, '?a:b': 2, "'m": 2}
# ['enter' 'go'] {'su:m': 17, '^be:ti:': 16, '^e:b': 20, 'baj': 17, '?ag': 12, 'tikw': 11, 'hasam': 8, 'r?': 17, 'gi:g': 14, '^imo:ra': 4, '^iwara': 4, '^aba:j': 3, 'be:nho:': 3, '^re:w': 4, "^'dha:j": 3, '^ne': 4, 'gar': 4, 'u:g': 3, 'idha': 3, 'tho:': 3, 'di': 7, '^j?': 10}
# ['important' 'old'] {}
# ['grateful' 'thank'] {}
# ['disappear' 'go'] {'kwid': 8, '^be:ti:': 16, '^e:b': 20, 'baj': 17, '?ag': 12, 'su:m': 10, 'tikw': 11, 'hasam': 8, 'r?': 17, 'gi:g': 14, '^imo:ra': 4, '^iwara': 4, '^aba:j': 3, 'be:nho:': 3, '^re:w': 4, "^'dha:j": 3, '^ne': 4, 'gar': 4, 'u:g': 3, 'idha': 3, 'tho:': 3, 'di': 7, '^j?': 10}
# ['dig' 'take'] {'^firk': 7, 'rik': 5, '^til?it$': 2, '^fitik$': 2, '^farri:': 2, 'ks': 22, 'abik': 24, '^ah': 17, 'sallama': 8, 'ni:n': 7, 'ambi:k': 5, 'fir?a': 6, '^ta:wti:t$': 3, 'fit': 4, '^tendije:k$': 2, "^a'hi:t$": 2, '^nu:nam': 2, 'ha:jt$': 2, 'he:n': 3, 'alak': 3, "^o:'": 2, 'kja': 2, 'r?i$': 2, '?a:b': 2, "'m": 2}
# ['bear' 'produce'] {}
# ['day' 'past'] {'ams': 19, 'ji:n': 9, 'b?e': 6, '^lh': 7, 'dama': 3, '^be:tej$': 2, '^b?ik': 2}
# ['drink' 'eat'] {'gw?': 36, 'tam': 45, '^a:m': 3, '^?a:me': 2}
# ['leave' 'throw'] {'gi:g': 55, 'ndi:f': 10, '?is': 11, '^isti$': 6, '^whidz$': 3, 'diwo': 2, 'ie:': 2, 'sa:b': 3, '^itfar?': 2, 'alla:j': 2, 'arim': 2, '^misi$': 2, '^akaje:$': 2, 'di': 33, 'ngi': 15, 'gid': 12, 'ho:so:$': 3, 'ha:s$': 2}
# ['end' 'last'] {'xaro:$': 2, 'ni:wa': 2}
# ['cow' 'meat'] {'s?a': 5, 'sala': 17, 'sa:t': 7, 'to:s': 5, 'do:f$': 2}
# ['mother' 'mum'] {}
# ['collect' 'gather'] {}
# ['become' 'come'] {'ke': 31, 'rawe:sa': 8, 'ikat': 13, '^aka:': 6, 'anki:re': 3, '^aslim': 3, '?ak': 4, 'i:kt': 4, '^aki$': 2, '^e:tmi:': 2, 'e:ji$': 2, '^idama:n$': 2, '^so:d': 2, '^gu:d': 2, '^lhi:': 2, 'iktij': 2, 'i:dh': 2, '^j?': 130, '^e:ja': 23, '^e:ti': 8, '?e:': 16, '^u:mha$': 5, '^e:nan': 3, 'the:b$': 5, 'ba?': 3, '?o:ri$': 3, ':si:n': 3, '^?i': 4, 'e:tn': 3, 'tije:b$': 3, 'adz': 3}
# ['tell' 'warn'] {}
# ['tomorrow' 'yesterday'] {'lhajt': 7, '^lhe': 2, '^ir$': 3}
# ['look' 'seek'] {'sib': 26, 'sambi:b': 11, 'har': 16, "'ha": 4, 'rare': 3, 'it?i$': 2, "'rha$": 2, '^biddi': 2, 'i:ti:$': 2}
# ['attach' 'tie'] {'hakw': 2, 'kwir': 3, 'rri:ne:': 2}
# ['do' 'last'] {'sak': 21, 'id?': 10, 'go:je:': 3, '^rhisa': 3, 'war': 5, '^ba:we:ri:nhe:b$': 2, '^ho:k$': 3, '^i:wr': 2, 'saga:m': 3, 'tido:': 2, '^d?i:t$': 2, 'a:ja$': 2, '^e:dna$': 2, '^ki:k': 2}
# ['come' 'speak'] {}
# ['brother' 'sibling'] {}
# ['cut' 'leave'] {'^fassa': 5, '^to:jaj$': 5, 'kat?': 3, 'gi:g': 55, 'ndi:f': 10, '?is': 11, '^isti$': 6, '^whidz$': 3, 'diwo': 2, 'ie:': 2, 'sa:b': 3, '^itfar?': 2, 'alla:j': 2, 'arim': 2, '^misi$': 2, '^akaje:$': 2, 'di': 33}
# ['build' 'stop'] {'gad': 17, 'nga:d': 4, 'is?': 2}
# ['fight' 'quarrel'] {}
# ['grandfather' 'grandparent'] {}
# ['go' 'return'] {}
# ['happen' 'pass'] {'mmarr': 7, '^ha:l': 3, 'has': 8, '^do:ra': 3}
# ['evening' 'night'] {'^w?i:sa:jo:$': 3, 'girab$': 3, 'wa:d': 20, 'mas': 13, '^na:j': 6, 'haw': 3}
# ['feed' 'give'] {'^kalla:': 4, '^d?o:r': 4, ':w': 38, 'he:b': 27, 'niw': 9, 'kara:ma': 7, '^hi:': 9, '^sal': 7, '^hija': 3, '^iw$': 3, '^he': 5, '^gw?as': 3, 'ri:t$': 3, "hi:'": 2, 'kte:b$': 2, 'jaw': 2, '^tifir?': 2, '^nh': 2}
# ['call' 'use'] {'ali:': 18, 'dne': 12, '^da:jije:b$': 2, '^e:ne:?$': 2, '^ni:d': 2, '^nid?i': 3, '^harro:': 2, '^askin': 2, '^e:jam$': 2, '^hawa:': 2, '^b?i': 2, 'asti$': 2}
# ['love' 'want'] {'^esse': 2, '^are:j': 2, 'dije:': 5, 'we:na': 3, '^ijad$': 2, '^and': 4, '^saga:ma$': 2, '^di:t$': 3, '^arawe': 2, '^tama': 2, "^'a": 2, 'i:d': 6}
# ['pull' 'shoot'] {'sikwt': 8}
# ['big' 'grow'] {'ddigi': 5, '^akira$': 2, '^hire:ri:t$': 2, 'fu:l': 2}
# ['say' 'want'] {'e:n$': 456, 'di': 296, 'in': 126, ':dn': 33, 'ne:$': 41, '^ti:': 13, 'i:d': 18, 'dije:': 5, 'we:na': 3, '^ijad$': 2, '^and': 4, '^saga:ma$': 2, '^di:t$': 3, '^arawe': 2, '^tama': 2, "^'a": 2}
# ['marry' 'take'] {'d?ir': 17, 'ks': 22, 'abik': 24, '^ah': 17, 'sallama': 8, 'ni:n': 7, 'ambi:k': 5, 'fir?a': 6, '^ta:wti:t$': 3, 'fit': 4, '^tendije:k$': 2, "^a'hi:t$": 2, '^nu:nam': 2, 'ha:jt$': 2, 'he:n': 3, 'alak': 3, "^o:'": 2, 'kja': 2, 'r?i$': 2, '?a:b': 2, "'m": 2}
# ['make' 'prepare'] {'^kad': 7, 'se': 17, 'd?i': 12, '^dzaban': 4, 'w?ajiso': 3, 'isja:n': 3, 'ikwa:s': 3, 'tar': 5, '^dann?e': 4, 'stin': 3, '^gadabisinho:k$': 2, 'tikwikw': 2, 'sangad': 2, "w't": 2, 'si:n': 3, 'ma:s': 2, 'jho:b$': 2, 'a:jo:': 2, 'wu:': 2, 'tid$': 2, '^na:n$': 2, 'bisira': 4}
# ['drop' 'throw'] {'^d?i:t$': 2, 'idha': 2, 'ngi': 15, 'gid': 12, 'ho:so:$': 3, 'ha:s$': 2}
# ['frighten' 'frightened'] {'^ri': 2}
# ['live' 'living'] {'^aski': 12, '^mitija': 2}
# ['get' 'go'] {'^itambi:l$': 3, '^afir?a': 3, '^timir': 3, 'takwa:k': 2, 'dangar$': 2, '^i:biri': 3, 'tifir?a': 2, 'hak': 17, '^be:ti:': 16, '^e:b': 20, 'baj': 17, '?ag': 12, 'su:m': 10, 'tikw': 11, 'hasam': 8, 'r?': 17, 'gi:g': 14, '^imo:ra': 4, '^iwara': 4, '^aba:j': 3, 'be:nho:': 3, '^re:w': 4, "^'dha:j": 3, '^ne': 4, 'gar': 4, 'u:g': 3, 'idha': 3, 'tho:': 3, 'di': 7, '^j?': 10}
# Obs: 7339 / 12720

# %%
saturation_df = generate_saturation_dataframe(lexicon, arclics, tes)
saturation_df.to_csv(saturation_fn)
saturation_df

# %%
sns.histplot(saturation_df.ratio)

# %%
langs_per_field = pd.DataFrame({"field": [field[0] for field in fields], "nb_lang": [len([lang for lang in field[1] if len(field[1][lang]) > 0]) for field in fields]})
langs_per_field.to_csv(processed_data_path + 'langsxfield.csv')
langs_per_field.sort_values(by="nb_lang")

# %%
avg_terms_per_field = pd.DataFrame({"lang": tes.keys(), "avg_terms_per_field": [np.mean([len(field[1][lang]) for field in fields]) for lang in tes]})
avg_terms_per_field.to_csv(processed_data_path + 'avg_terms_per_field.csv')
avg_terms_per_field.sort_values(by="avg_terms_per_field", ascending=False)
#sns.barplot(data=avg_terms_per_field, x="lang", y="avg_terms_per_field")

# %%
# COUNTING MERGED STEM
merged_tes['beja1238'][1]['land' ]

for seed in merged_tes['beja1238'][0]:
    for stem in merged_tes['beja1238'][0][seed]:
        if 'ha:s' in stem:
            print(stem, seed)

# %%
select = {'ground', 'earth', 'land', 'country', 'world'}
lang = 'beja1238'

Counter([stem for seed in select if seed in merged_tes[lang][0] for stem in tes[lang][0][seed]])

# %%
select = {'ground', 'earth', 'land', 'country', 'world'}
lang = 'hoch1243'

len(merged_tes[lang][0]['land']['^maa$'])
# Out:
# 2
